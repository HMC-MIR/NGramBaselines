# %% [markdown]
# ### Load Dependencies

# %%
# %matplotlib inline
# %load_ext Cython

# %%
import numpy as np
import copy
from numpy.matlib import repmat
import matplotlib.pyplot as plt
from PIL import Image, ImageFilter, ImageChops
import cv2
from skimage import filters, measure
from skimage.measure import label, regionprops
from skimage.color import label2rgb
from sklearn.cluster import KMeans
import matplotlib.patches as mpatches
from scipy.signal import convolve2d
from scipy.spatial import KDTree
import seaborn as sns
import pickle
import librosa as lb
import time
import cProfile
import os
import os.path
import pyximport; pyximport.install()
import multiprocessing
from ExtractBootlegFeatures import *
# Out:
# The Cython extension is already loaded. To reload it, use:
#   %reload_ext Cython

# %% [markdown]
# ### Cython DTW

# %%
dtw_steps = [1,1,1,2,2,1] # dtw
dtw_weights = [1,1,2]

# %%
# %%cython
# import numpy as np
# cimport numpy as np
# cimport cython
#
# import sys
# import time
#
#
# DTYPE_INT32 = np.int32
# ctypedef np.int32_t DTYPE_INT32_t
#
# DTYPE_FLOAT = np.float64
# ctypedef np.float64_t DTYPE_FLOAT_t
#
# cdef DTYPE_FLOAT_t MAX_FLOAT = float('inf')
#
# # careful, without bounds checking can mess up memory - also can't use negative indices I think (like x[-1])
# @cython.boundscheck(False) # turn off bounds-checking for entire function
# def DTW_Cost_To_AccumCostAndSteps(Cin, parameter):
#     '''
#     Inputs
#         C: The cost Matrix
#     '''
#
#
#     '''
#     Section for checking and catching errors in the inputs
#     '''
#
#     cdef np.ndarray[DTYPE_FLOAT_t, ndim=2] C
#     try:
#         C = np.array(Cin, dtype=DTYPE_FLOAT)
#     except TypeError:
#         print(bcolors.FAIL + "FAILURE: The type of the cost matrix is wrong - please pass in a 2-d numpy array" + bcolors.ENDC)
#         return [-1, -1, -1]
#     except ValueError:
#         print(bcolors.FAIL + "FAILURE: The type of the elements in the cost matrix is wrong - please have each element be a float (perhaps you passed in a matrix of ints?)" + bcolors.ENDC)
#         return [-1, -1, -1]
#
#     cdef np.ndarray[np.uint32_t, ndim=1] dn
#     cdef np.ndarray[np.uint32_t, ndim=1] dm
#     cdef np.ndarray[DTYPE_FLOAT_t, ndim=1] dw
#     # make sure dn, dm, and dw are setup
#     # dn loading and exception handling
#     if ('dn'  in parameter.keys()):
#         try:
#
#             dn = np.array(parameter['dn'], dtype=np.uint32)
#         except TypeError:
#             print(bcolors.FAIL + "FAILURE: The type of dn (row steps) is wrong - please pass in a 1-d numpy array that holds uint32s" + bcolors.ENDC)
#             return [-1, -1, -1]
#         except ValueError:
#             print(bcolors.FAIL + "The type of the elements in dn (row steps) is wrong - please have each element be a uint32 (perhaps you passed a long?). You can specify this when making a numpy array like: np.array([1,2,3],dtype=np.uint32)" + bcolors.ENDC)
#             return [-1, -1, -1]
#     else:
#         dn = np.array([1, 1, 0], dtype=np.uint32)
#     # dm loading and exception handling
#     if 'dm'  in parameter.keys():
#         try:
#             dm = np.array(parameter['dm'], dtype=np.uint32)
#         except TypeError:
#             print(bcolors.FAIL + "FAILURE: The type of dm (col steps) is wrong - please pass in a 1-d numpy array that holds uint32s" + bcolors.ENDC)
#             return [-1, -1, -1]
#         except ValueError:
#             print(bcolors.FAIL + "FAILURE: The type of the elements in dm (col steps) is wrong - please have each element be a uint32 (perhaps you passed a long?). You can specify this when making a numpy array like: np.array([1,2,3],dtype=np.uint32)" + bcolors.ENDC)
#             return [-1, -1, -1]
#     else:
#         print(bcolors.FAIL + "dm (col steps) was not passed in (gave default value [1,0,1]) " + bcolors.ENDC)
#         dm = np.array([1, 0, 1], dtype=np.uint32)
#     # dw loading and exception handling
#     if 'dw'  in parameter.keys():
#         try:
#             dw = np.array(parameter['dw'], dtype=DTYPE_FLOAT)
#         except TypeError:
#             print(bcolors.FAIL + "FAILURE: The type of dw (step weights) is wrong - please pass in a 1-d numpy array that holds floats" + bcolors.ENDC)
#             return [-1, -1, -1]
#         except ValueError:
#             print(bcolors.FAIL + "FAILURE:The type of the elements in dw (step weights) is wrong - please have each element be a float (perhaps you passed ints or a long?). You can specify this when making a numpy array like: np.array([1,2,3],dtype=np.float64)" + bcolors.ENDC)
#             return [-1, -1, -1]
#     else:
#         dw = np.array([1, 1, 1], dtype=DTYPE_FLOAT)
#         print(bcolors.FAIL + "dw (step weights) was not passed in (gave default value [1,1,1]) " + bcolors.ENDC)
#
#
#     '''
#     Section where types are given to the variables we're going to use
#     '''
#     # create matrices to store our results (D and E)
#     cdef DTYPE_INT32_t numRows = C.shape[0] # only works with np arrays, use np.shape(x) will work on lists? want to force to use np though?
#     cdef DTYPE_INT32_t numCols = C.shape[1]
#     cdef DTYPE_INT32_t numDifSteps = np.size(dw)
#
#     cdef unsigned int maxRowStep = max(dn)
#     cdef unsigned int maxColStep = max(dm)
#
#     cdef np.ndarray[np.uint32_t, ndim=2] steps = np.zeros((numRows,numCols), dtype=np.uint32)
#     cdef np.ndarray[DTYPE_FLOAT_t, ndim=2] accumCost = np.ones((maxRowStep + numRows, maxColStep + numCols), dtype=DTYPE_FLOAT) * MAX_FLOAT
#
#     cdef DTYPE_FLOAT_t bestCost
#     cdef DTYPE_INT32_t bestCostIndex
#     cdef DTYPE_FLOAT_t costForStep
#     cdef unsigned int row, col
#     cdef unsigned int stepIndex
#
#     '''
#     The start of the actual algorithm, now that all our variables are set up
#     '''
#     # initializing the cost matrix - depends on whether its subsequence DTW
#     # essentially allow us to hop on the bottom anywhere (so could start partway through one of the signals)
#     if parameter['SubSequence']:
#         for col in range(numCols):
#             accumCost[maxRowStep, col + maxColStep] = C[0, col]
#     else:
#         accumCost[maxRowStep, maxColStep] = C[0,0]
#
#     # filling the accumulated cost matrix
#     for row in range(maxRowStep, numRows + maxRowStep, 1):
#         for col in range(maxColStep, numCols + maxColStep, 1):
#             bestCost = accumCost[<unsigned int>row, <unsigned int>col] # initialize with what's there - so if is an entry point, then can start low
#             bestCostIndex = 0
#             # go through each step, find the best one
#             for stepIndex in range(numDifSteps):
#                 #costForStep = accumCost[<unsigned int>(row - dn[<unsigned int>(stepIndex)]), <unsigned int>(col - dm[<unsigned int>(stepIndex)])] + dw[<unsigned int>(stepIndex)] * C[<unsigned int>(row - maxRowStep), <unsigned int>(col - maxColStep)]
#                 costForStep = accumCost[<unsigned int>((row - dn[(stepIndex)])), <unsigned int>((col - dm[(stepIndex)]))] + dw[stepIndex] * C[<unsigned int>(row - maxRowStep), <unsigned int>(col - maxColStep)]
#                 if costForStep < bestCost:
#                     bestCost = costForStep
#                     bestCostIndex = stepIndex
#             # save the best cost and best cost index
#             accumCost[row, col] = bestCost
#             steps[<unsigned int>(row - maxRowStep), <unsigned int>(col - maxColStep)] = bestCostIndex
#
#     # return the accumulated cost along with the matrix of steps taken to achieve that cost
#     return [accumCost[maxRowStep:, maxColStep:], steps]
#
# @cython.boundscheck(False) # turn off bounds-checking for entire function
# def DTW_GetPath(np.ndarray[DTYPE_FLOAT_t, ndim=2] accumCost, np.ndarray[np.uint32_t, ndim=2] stepsForCost, parameter):
#     '''
#
#     Parameter should have: 'dn', 'dm', 'dw', 'SubSequence'
#     '''
#
#     cdef np.ndarray[unsigned int, ndim=1] dn
#     cdef np.ndarray[unsigned int, ndim=1] dm
#     cdef np.uint8_t subseq
#     # make sure dn, dm, and dw are setup
#     if ('dn'  in parameter.keys()):
#         dn = parameter['dn']
#     else:
#         dn = np.array([1, 1, 0], dtype=DTYPE_INT32)
#     if 'dm'  in parameter.keys():
#         dm = parameter['dm']
#     else:
#         dm = np.array([1, 0, 1], dtype=DTYPE_INT32)
#     if 'SubSequence' in parameter.keys():
#         subseq = parameter['SubSequence']
#     else:
#         subseq = 0
#
#     cdef np.uint32_t numRows
#     cdef np.uint32_t numCols
#     cdef np.uint32_t curRow
#     cdef np.uint32_t curCol
#     cdef np.uint32_t endCol
#     cdef DTYPE_FLOAT_t endCost
#
#     numRows = accumCost.shape[0]
#     numCols = accumCost.shape[1]
#
#     # either start at the far corner (non sub-sequence)
#     # or start at the lowest cost entry in the last row (sub-sequence)
#     # where all of the signal along the row has been used, but only a
#     # sub-sequence of the signal along the columns has to be used
#     curRow = numRows - 1
#     if subseq:
#         curCol = np.argmin(accumCost[numRows - 1, :])
#     else:
#         curCol = numCols - 1
#
#     endCol = curCol
#     endCost = accumCost[curRow, curCol]
#
#     cdef np.uint32_t curRowStep
#     cdef np.uint32_t curColStep
#     cdef np.uint32_t curStepIndex
#
#
#     cdef np.ndarray[np.uint32_t, ndim=2] path = np.zeros((2, numRows + numCols), dtype=np.uint32) # make as large as could need, then chop at the end
#     path[0, 0] = curRow
#     path[1, 0] = curCol
#
#     cdef np.uint32_t stepsInPath = 1 # starts at one, we add in one before looping
#     cdef np.uint32_t stepIndex = 0
#     cdef np.int8_t done = (subseq and curRow == 0) or (curRow == 0 and curCol == 0)
#     while not done:
#         if accumCost[curRow, curCol] == MAX_FLOAT:
#             print('A path is not possible')
#             break
#
#         # you're done if you've made it to the bottom left (non sub-sequence)
#         # or just the bottom (sub-sequence)
#         # find the step size
#         curStepIndex = stepsForCost[curRow, curCol]
#         curRowStep = dn[curStepIndex]
#         curColStep = dm[curStepIndex]
#         # backtrack by 1 step
#         curRow = curRow - curRowStep
#         curCol = curCol - curColStep
#         # add your new location onto the path
#         path[0, stepsInPath] = curRow
#         path[1, stepsInPath] = curCol
#         stepsInPath = stepsInPath + 1
#         # check to see if you're done
#         done = (subseq and curRow == 0) or (curRow == 0 and curCol == 0)
#
#     # reverse the path (a matrix with two rows) and return it
#     return [np.fliplr(path[:, 0:stepsInPath]), endCol, endCost]
#
# class bcolors:
#     HEADER = '\033[95m'
#     OKBLUE = '\033[94m'
#     OKGREEN = '\033[92m'
#     WARNING = '\033[93m'
#     FAIL = '\033[91m'
#     ENDC = '\033[0m'
#     BOLD = '\033[1m'
#     UNDERLINE = '\033[4m'

# %%
def alignBootlegScores(query, ref, numRefNotes, steps = [1,1,1,2,2,1], weights = [1,1,2], optimized=True):
    if optimized: # Cython implementation
        # set params
        assert len(steps) % 2 == 0, "The length of steps must be even."
        dn = np.array(steps[::2], dtype=np.uint32)
        dm = np.array(steps[1::2], dtype=np.uint32)
        dw = weights
        subsequence = True
        parameter = {'dn': dn, 'dm': dm, 'dw': dw, 'SubSequence': subsequence}

        # Compute cost matrix
        #cost = costMetric(query.T, ref)
        numQueryNotes = np.sum(query, axis=0)
        cost = normalizedCostMetric(query, ref, numQueryNotes, numRefNotes)

        # DTW
        [D, s] = DTW_Cost_To_AccumCostAndSteps(cost, parameter)
        [wp, endCol, endCost] = DTW_GetPath(D, s, parameter)

        # Reformat the output
        wp = wp.T[::-1]
    else: # librosa implementation
        steps = np.array(steps).reshape((-1,2))
        D, wp = lb.sequence.dtw(query, ref, step_sizes_sigma = steps, weights_mul = weights, subseq = True, metric = costMetric)
    return D, wp

# %% [markdown]
# ### Get Bootleg Score of Query Image

# %%
imagefile = 'data/queries/p111_q2.jpg'
pim1 = Image.open(imagefile).convert('L')
pim1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-bf8c5a01b9cd> in <module>
#       1 imagefile = 'data/queries/p111_q2.jpg'
# ----> 2 pim1 = Image.open(imagefile).convert('L')
#       3 pim1
#
# ~/.conda/envs/MIR4/lib/python3.6/site-packages/PIL/Image.py in open(fp, mode)
#    2768
#    2769     if filename:
# -> 2770         fp = builtins.open(filename, "rb")
#    2771         exclusive_fp = True
#    2772
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/queries/p111_q2.jpg'

# %%
bscore_query=processQuery(imagefile)
visualizeLongBootlegScore(bscore_query, [13,15,17,19,21,35,37,39,41,43])

# %% [markdown]
# ### Load Reverse Index

# %%
pickle_file = 'experiments/indices/SINGULAR.pkl'
with open(pickle_file, 'rb') as f:
    rindex = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-9d9cd56f3e5c> in <module>
#       1 pickle_file = 'experiments/indices/SINGULAR.pkl'
# ----> 2 with open(pickle_file, 'rb') as f:
#       3     rindex = pickle.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'experiments/indices/SINGULAR.pkl'

# %% [markdown]
# ### Generate Histograms

# %%
def bootlegHash(arr):
    bitstring = ""
    for i in range(len(arr)):
        if arr[i]==1:
            bitstring+="1"
        else:
            bitstring +="0"
    bitstring = bitstring+"00"
    hashint = int(bitstring, 2)
    hashint = np.uint64(hashint)
    return hashint

# %%
def showHistograms(arr,numBins):
    plt.hist(arr, normed=False, bins=numBins)
    plt.show()

# %%
def getOffsetDelta(bscore_query, rindex):
    offsetDict = {}
    for index in range(len(bscore_query.T)):
        hashkey = bootlegHash(bscore_query.T[index])
        if hashkey ==0 or not hashkey in rindex:
            continue
        rindex_hash = rindex[hashkey]
        #print(len(rindex_hash))
        for key in rindex_hash:
            #DONT USE np.ARRAY
            offset = [i - index for i in rindex_hash[key]]
            if key in offsetDict:
                offsetDict[key].extend(offset)
            else:
                offsetDict[key]=offset
    return offsetDict

# %%
def getOffsetDeltaNGram(bscore_query, rindex, N_Gram = 3):
    offsetDict = {}
    for index in range(len(bscore_query.T)):
        hashkey = []
        try:
            for i in range(N_Gram):
                hashkey.append(bootlegHash(bscore_query.T[index+i]))
        except IndexError:
            continue
        hashkey = tuple(hashkey)
        if hashkey == 0 or not hashkey in rindex:
            continue
        rindex_hash = rindex[hashkey]
        for key in rindex_hash:
            #DONT USE np.ARRAY
            offset = [i - index for i in rindex_hash[key]]
            if key in offsetDict:
                offsetDict[key].extend(offset)
            else:
                offsetDict[key]=offset
    return offsetDict

# %%
def getOffsetDeltaDynamicStaticN_GRAM(bscore_query, rindices, counts, threshold, Max_N = 4):
    offsetDict = {}
    for index in range(len(bscore_query.T)):
        N_Gram = 1
        while(True):
            hashkey = []
            try:
                for i in range(N_Gram):
                    hashkey.append(bootlegHash(bscore_query.T[index+i]))
            except IndexError:
                break
            rindex = rindices[N_Gram-1]
            hashkey = tuple(hashkey)
            if not hashkey in rindex:
                break
            numMatches = counts[N_Gram-1][hashkey]
            if numMatches < threshold or N_Gram == Max_N:
                rindex_hash = rindex[hashkey]
                for key in rindex_hash:
                    #DONT USE np.ARRAY
                    offset = [i - index for i in rindex_hash[key]]
                    if key in offsetDict:
                        offsetDict[key].extend(offset)
                    else:
                        offsetDict[key]=offset
                break
            N_Gram+=1
    return offsetDict

# %%
def getOffsetDeltaDynamicAdaptiveN_GRAM(bscore_query, rindices, counts, K_total, Max_N = 4):
    # K_avg is the total allocation to each fingerprint
    K_avg = K_total / len(bscore_query.T)
    K_carry = 0
    offsetDict = {}
    for index in range(len(bscore_query.T)):
        N_Gram = 1
        while(True):
            hashkey = []
            try:
                for i in range(N_Gram):
                    hashkey.append(bootlegHash(bscore_query.T[index+i]))
            except IndexError:
                break
            rindex = rindices[N_Gram-1]
            hashkey = tuple(hashkey)
            if not hashkey in rindex:
                break
            numMatches = counts[N_Gram-1][hashkey]
            if numMatches < K_avg + K_carry or N_Gram == Max_N:
                K_carry += K_avg - numMatches
                #NOTE: We try to avoid negative K_carry, but because of the cap in Max_N, we need to be careful.
                rindex_hash = rindex[hashkey]
                for key in rindex_hash:
                    offset = [i - index for i in rindex_hash[key]]
                    if key in offsetDict:
                        offsetDict[key].extend(offset)
                    else:
                        offsetDict[key]=offset
                break
            N_Gram+=1
    return offsetDict

# %%
def rankHistograms(offsetDict, rindex, bin_size=10):
    histograms = {}
    bin_size = 10
    pieceScores = []
    numShow = 5
    for key in offsetDict:
        h = offsetDict[key]
        maxh = max(h)
        minh = min(h)
        if(maxh > minh+bin_size):
            hist = [0 for i in range(int((maxh-minh)/bin_size)+2)]
            for i in h:
                hist[int((i-minh)/bin_size)]+=1
            score = max(hist)
            pieceScores.append((key, score))
            
    pieceScores = sorted(pieceScores, key = lambda x:x[1], reverse=True)
    return pieceScores, histograms

# %%
offsetDict = getOffsetDelta(bscore_query,rindex)
pieceScores, histograms = rankHistograms(offsetDict,rindex)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-137e78142e30> in <module>
# ----> 1 offsetDict = getOffsetDelta(bscore_query,rindex)
#       2 pieceScores, histograms = rankHistograms(offsetDict,rindex)
#
# NameError: name 'bscore_query' is not defined

# %%
def displayHist(pieceScores, pieceNum):
    pieceScores1 = sorted(pieceScores, key = lambda x:int(x[0][1:]))
    print(pieceScores1[pieceNum-1][0])
    h,numBins = histograms[pieceScores1[pieceNum-1][0]]
    showHistograms(h,numBins)

# %%
for i in range(5):
    print(pieceScores[i])
h,numBins = histograms[pieceScores[0][0]]
showHistograms(h,numBins)

displayHist(pieceScores, 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-e7f97e0d0aea> in <module>
#       1 for i in range(5):
# ----> 2     print(pieceScores[i])
#       3 h,numBins = histograms[pieceScores[0][0]]
#       4 showHistograms(h,numBins)
#       5
#
# NameError: name 'pieceScores' is not defined

# %%
pieceStr = pieceScores[0][0]
midi_db_dir = 'experiments/train/db'
midi_bscore_pkl = '{}/{}.pkl'.format(midi_db_dir,pieceStr)
if not os.path.exists(midi_bscore_pkl):
    midi_bscore_pkl = '{}/{}.pkl'.format(midi_db_dir,'p171')
midi_d = loadMidiBootlegScore(midi_bscore_pkl)

bscore_midi, miditimes, num_notes, stafflines = loadMidiBootlegScore(midi_bscore_pkl)
D, wp = alignBootlegScores(bscore_query, bscore_midi, num_notes, dtw_steps, dtw_weights)
matchSegmentTime, matchSegmentTick = getPredictedTimestamps(wp, miditimes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-dcccb11ed01f> in <module>
# ----> 1 pieceStr = pieceScores[0][0]
#       2 midi_db_dir = 'experiments/train/db'
#       3 midi_bscore_pkl = '{}/{}.pkl'.format(midi_db_dir,pieceStr)
#       4 if not os.path.exists(midi_bscore_pkl):
#       5     midi_bscore_pkl = '{}/{}.pkl'.format(midi_db_dir,'p171')
#
# NameError: name 'pieceScores' is not defined

# %%
def getRank(pieceScores,correctPiece):
    rank = 200
    for i in range(len(pieceScores)):
        if pieceScores[i][0]==correctPiece:
            rank=i+1
    return rank

# %%
getRank(pieceScores, os.path.basename(imagefile).split('_')[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-acc48aa119ca> in <module>
# ----> 1 getRank(pieceScores, os.path.basename(imagefile).split('_')[0])
#
# NameError: name 'pieceScores' is not defined

# %% [markdown]
# ### Run system on all files

# %%
def processSingleQuery(imagefile, rindex, counts = None, outfile = None, mode = "N_GRAM"):
    if outfile is not None and os.path.exists(outfile):
        print("SKIPPED",outfile)
        return
    profileStart = time.time()
    
    # Get Bootleg Score
    bscore_query=processQuery(imagefile)
    
    # Generate and rank histograms
    if mode == "NORMAL":
        offsetDict = getOffsetDelta(bscore_query, rindex)
    elif mode == "N_GRAM":
        offsetDict = getOffsetDeltaNGram(bscore_query, rindex, N_Gram = 1)
    elif mode == "Dynamic_Static":
        offsetDict = getOffsetDeltaDynamicStaticN_GRAM(bscore_query, rindices=rindex, counts=counts, threshold=1000, Max_N=4)
    elif mode == "Dynamic_Adaptive":
        offsetDict = getOffsetDeltaDynamicAdaptiveN_GRAM(bscore_query, rindices=rindex, counts=counts, K_total=50000, Max_N=4)
    pieceScores, histograms = rankHistograms(offsetDict, rindex)
    
    # Profile & save to file
    profileEnd = time.time()
    profileDur = profileEnd - profileStart
    print(profileDur)
    saveToFile(outfile, imagefile, pieceScores, profileDur)

    return pieceScores

# %%
def saveToFile(outfile, imagefile, pieceScores, profileDur):
    if outfile:
        with open(outfile, 'wb') as f:
            query = os.path.splitext(os.path.basename(imagefile))[0]
            pickle.dump((query,pieceScores, profileDur),f)

# %%
st = time.time()
pickle_file = 'experiments/indices/N_GRAM_1_ALL.pkl'
with open(pickle_file, 'rb') as f:
    rindex1 = pickle.load(f)
print("LOADED pkl file")
rindex_filter = rindex1
print("Total Time: ",time.time()-st)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-2d1f765b3a67> in <module>
#       1 st = time.time()
#       2 pickle_file = 'experiments/indices/N_GRAM_1_ALL.pkl'
# ----> 3 with open(pickle_file, 'rb') as f:
#       4     rindex1 = pickle.load(f)
#       5 print("LOADED pkl file")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'experiments/indices/N_GRAM_1_ALL.pkl'

# %%
# Condense if using selectedfp
condense = False
if condense :
    rindex_filter = copy.deepcopy(rindex1)
    for key in rindex1:
        s = 0
        for piece in rindex1[key].keys():
            s +=len(rindex1[key][piece])
        if s > 10000:
            rindex_filter.pop(key, None)
print("Total Time: ",time.time()-st)
# Out:
# Total Time:  3.7014214992523193

# %%
st = time.time()
Max_N = 4
rindex_filter = []
fpMaps = []
counts = []
for i in range(1, Max_N+1):
    print("LOADING {}".format(i))
    pickle_file = 'experiments/indices/N_GRAM_{}_ALL.pkl'.format(i)
    count_file = 'experiments/indices/N_GRAM_{}_COUNT.pkl'.format(i)
    with open(pickle_file, 'rb') as f:
        rindex_filter.append(pickle.load(f))
        f.flush()
        f.close()
    with open(count_file, 'rb') as f:
        counts.append(pickle.load(f))
        f.flush()
        f.close()
print("LOADED pkl files")
print("Total Time: ",time.time()-st)
# Out:
# LOADING 1
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-25-7f1df84190f4> in <module>
#       8     pickle_file = 'experiments/indices/N_GRAM_{}_ALL.pkl'.format(i)
#       9     count_file = 'experiments/indices/N_GRAM_{}_COUNT.pkl'.format(i)
# ---> 10     with open(pickle_file, 'rb') as f:
#      11         rindex_filter.append(pickle.load(f))
#      12         f.flush()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'experiments/indices/N_GRAM_1_ALL.pkl'

# %%
# process single query
#counts = []
query_file = '/home/dyang/SheetMidiSearchRetrieval/data/queries/p2_q1.jpg'
processSingleQuery(query_file, rindex_filter, counts = counts, mode = "Dynamic_Static")
# Out:
# Processing /home/dyang/SheetMidiSearchRetrieval/data/queries/p2_q1.jpg
# 1.3250157833099365
# [('dGouin,_PierreNocturnes,_Op.9_**86550', 54),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricNocturnes,_Op.9_**86550', 54),
#  ('p2', 54),
#  ('dGouin,_PierreNocturnes,_Op.9_**34915', 33),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricNocturnes,_Op.9_**34915', 33),
#  ('dGouin,_PierreNocturnes,_Op.9_**80717', 32),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricNocturnes,_Op.9_**80717', 32),
#  ('dGouin,_PierreNocturnes,_Op.9_**00470', 31),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricNocturnes,_Op.9_**00470', 31),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricNocturnes,_Op.9_**34916', 30),
#  ('dGouin,_PierreNocturnes,_Op.9_**34916', 30),
#  ('dGouin,_PierreNocturnes,_Op.9_**112335', 29),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricNocturnes,_Op.9_**112335', 29),
#  ('dGouin,_PierreNocturnes,_Op.9_**113996', 23),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricNocturnes,_Op.9_**113996', 23),
#  ('dStenhammar,_WilhelmPiano_Sonata,_Op.12_**400268', 10),
#  ('dCramer,_HenriAm_Clavier,_Op.120_**522114', 9),
#  ('dNeupert,_Edmund12_New_Octave_Studies_**309696', 8),
#  ('dLebierre,_OlivierDie_Zauberin_von_der_Schelde,_Op.68_**409750', 7),
#  ('dMozart,_Wolfgang_AmadeusPiano_Sonata_No.1_in_C_major,_K.279**56310', 7),
#  ('dHeckle,_A._F.La_Golondrina_Fantasia_**362106', 6),
#  ('dHummel,_Johann_NepomukLa_bella_capricciosa,_Op.55_**72472', 6),
#  ('dCornisset,_GustaveLa_myst%C3%A9rieuse_**95516', 6),
#  ('dHeller,_StephenBolero,_Op.32_**07022', 5),
#  ('dKnight,_Joseph_PhilipThe_Clifton_Waltz_**515523', 5),
#  ('dHaslinger,_TobiasDas_neubegl%C3%BCckte_Oesterreich,_Op.18_**441836', 5),
#  ('dSchubert,_FranzPiano_Sonata_No.19,_D.958_**55384', 5),
#  ('dAufsess,_Hans_von5_Walzer,_Op.4_**152622', 5),
#  ('dMozart,_Wolfgang_AmadeusPiano_Sonata_No.1_in_C_major,_K.279**82506', 5),
#  ('dLiszt,_FranzHungarian_Rhapsody_No.2,_S.244**300584', 5),
#  ('dLiszt,_FranzHungarian_Rhapsody_No.2,_S.244**33352', 5),
#  ('dZikoff,_FriedrichKugel_und_Kegel_Galop,_Op.81_**415003', 4),
#  ('dJoseffy,_RafaelSouvenir_d%E2%80%99Am%C3%A9rique_**46876', 4),
#  ('dKohler,_EmileLes_5_parties_du_monde_**298109', 4),
#  ('dRichards,_BrinleyIn_Foreign_Lands,_Op.67**38358', 4),
#  ('dTeilman,_ChristianKristiania-Quadrille,_Op.39_**296220', 4),
#  ('dSchulz-Weida,_JosephEin_Morgen_im_Gebirge,_Op.102_**416742', 4),
#  ('dHegermann-Lindencrone,_Lillie_deDivin_sourire_**440019', 4),
#  ('dSchubert,_FranzPiano_Sonata_No.19,_D.958_**00360', 4),
#  ('dLack,_Th%C3%A9odoreSorrentina,_Op.96_**44454', 4),
#  ('dBohm,_Carl3_Piano_Pieces,_Op.259_**386329', 4),
#  ('dEgghard,_JulesPaola,_Op.245_**130739', 4),
#  ('dRubinstein,_AntonLes_gloires_du_piano_**432578', 4),
#  ('dHummel,_Johann_NepomukVariations_on_a_Theme_from_%27Armide%27,_Op.57_**67735',
#   4),
#  ('dHummel,_Johann_NepomukVariations_on_a_Theme_from_%27Armide%27,_Op.57_**67736',
#   4),
#  ('dLiszt,_FranzHungarian_Rhapsody_No.2,_S.244**42480', 4),
#  ('dGranados,_EnriqueEscenas_Rom%C3%A1nticas_**01202', 4),
#  ('dDesormes,_Louis_C%C3%A9sarMarseille_**256406', 4),
#  ('dFoschini,_Gaetano_FerdinandoBrise_du_Bosphore,_Op.24_**303400', 4),
#  ('dZar%C4%99bski,_Juliusz4_Morceaux,_Opp.28-31_**503849', 4),
#  ('dScharwenka,_XaverMeisterschule_**03756', 4),
#  ('dPrudent,_%C3%89mile%C3%89tudes_de_genre_pour_le_piano,_Op.16_**311969', 4),
#  ('dB%C3%BClow,_Hans_vonLacerta,_Op.27_**97837', 4),
#  ('dHummel,_Johann_NepomukPiano_Sonata_No.5,_Op.81_**78600', 3),
#  ('dLoder,_Edward_JamesIntroduction_and_Rondo_Brillant,_Op.17_**290268', 3),
#  ('dRaff,_Joachim2_Piano_Pieces,_Op.157_**15357', 3),
#  ('dStaab,_JohannFliegende_Bl%C3%A4tter,_Op.70_**62213', 3),
#  ('dMendelssohn,_FelixVariations_s%C3%A9rieuses,_Op.54_**103384', 3),
#  ('dHaberbier,_ErnstSaltarella,_Op.54_**183134', 3),
#  ('dBlandner,_Charles_F.Vinetta,_valse_de_salon_**101880', 3),
#  ('dLiszt,_Franz%C3%89tudes_d%27ex%C3%A9cution_transcendante,_S.139_**67094',
#   3),
#  ('dMendelssohn,_FelixVariations_s%C3%A9rieuses,_Op.54_**52135', 3),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricRondo_%C3%A0_la_mazur,_Op.5_**86487', 3),
#  ('dGermer,_HeinrichAlbum_ausgew%C3%A4hlter_Vortragsst%C3%BCcke_**456453', 3),
#  ('dMendelssohn,_FelixVariations_s%C3%A9rieuses,_Op.54_**103385', 3),
#  ('dCarre%C3%B1o,_Teresa2_Esquisses_italiennes,_Opp.33-34_**255631', 3),
#  ('dGottschalk,_Louis_MoreauLe_Bananier,_Op.5_**07712', 3),
#  ('dGottschalk,_Louis_MoreauLe_Bananier,_Op.5_**106670', 3),
#  ('dLack,_Th%C3%A9odoreLes_violettes,_Op.3_**256503', 3),
#  ('dRaff,_JoachimValse_brillante,_Op.156_**15359', 3),
#  ('dPaderewski,_Ignacy_JanIntermezzo_No.2_**392174', 3),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricRondo_%C3%A0_la_mazur,_Op.5_**400813', 3),
#  ('dBredal,_Ivar_FrederikPotpourri_de_l%27Op%C3%A9ra_%27Les_Guerillas%27_**394052',
#   3),
#  ('dGottschalk,_Louis_MoreauLe_Bananier,_Op.5_**125609', 3),
#  ('dSchubert,_Franz12_Grazer_Waltzer,_D.924_**53751', 3),
#  ('dBattmann,_Jacques-LouisAnna-polka_**516214', 3),
#  ('dKaulich,_JosefVielliebchen-Polka,_Op.101_**261142', 3),
#  ('dMazurette,_SalomonPauline,_Op.145_**112105', 3),
#  ('dSuk,_JosefLife_and_Dreams,_Op.30_**25654', 3),
#  ('dMattei,_TitoGrande_valse_de_concert_**512476', 3),
#  ('dGouvy,_Louis_Th%C3%A9odore2_Etudes,_Op.1_**11310', 3),
#  ('dBach,_Johann_SebastianOrgan_Concerto_in_C_major,_BWV_594_**04403', 3),
#  ('dVorontsova,_MariyaAlbum_of_Favorite_Songs_**299821', 3),
#  ('dBulakhov,_PyotrAlbum_of_Favorite_Songs_**387740', 3),
#  ('dWielhorski,_Micha%C5%82Album_of_Favorite_Songs_**387740', 3),
#  ('dZhilin,_AlekseyAlbum_of_Favorite_Songs_**299821', 3),
#  ('dWeber,_Carl_Maria_vonPiano_Sonata_No.2_in_A-flat_major,_Op.39_**04407', 3),
#  ('dKochubey,_YelizavetaAlbum_of_Favorite_Songs_**299821', 3),
#  ('dKochubey,_YelizavetaAlbum_of_Favorite_Songs_**387740', 3),
#  ('dCzerny,_CarlPianoforte-Schule,_Op.500_**356507', 3),
#  ('dPashkov,_NikolayAlbum_of_Favorite_Songs_**387740', 3),
#  ('dDerviz,_NikolayAlbum_of_Favorite_Songs_**387740', 3),
#  ('dStarke,_FriedrichWiener_Pianoforte_Schule,_Op.108_**495098', 3),
#  ('dMorandi,_GiovanniSuonate_per_accompagnamento_d%27una_Messa_solenne_**106720',
#   3),
#  ('dKlimovsky,_YevgenyAlbum_of_Favorite_Songs_**299821', 3),
#  ('dRosas,_JuventinoSobre_las_olas_**357291', 3),
#  ('dVorontsova,_MariyaAlbum_of_Favorite_Songs_**387740', 3),
#  ('dDonaurov,_SergeyAlbum_of_Favorite_Songs_**387740', 3),
#  ('dShashina,_YelizavetaAlbum_of_Favorite_Songs_**387740', 3),
#  ('dCzerny,_CarlPractical_Exercises_for_Beginners,_Op.599_**245651', 3),
#  ('dZhilin,_AlekseyAlbum_of_Favorite_Songs_**387740', 3),
#  ('dHummel,_Johann_NepomukLa_bella_capricciosa,_Op.55_**72471', 3),
#  ('dPaufler,_Christian_HeinrichAlbum_of_Favorite_Songs_**299821', 3),
#  ('dKlimovsky,_YevgenyAlbum_of_Favorite_Songs_**387740', 3),
#  ('dMaylath,_HenryThe_Crusader%27s_Return_**381603', 3),
#  ('dMozart,_Wolfgang_Amadeus12_Variations_on_a_Minuet_by_Fischer,_K.179**86721',
#   3),
#  ('dOre,_AdamAlbum_Balticum_**258092', 3),
#  ('dSchumann,_RobertPapillons,_Op.2_**28361', 3),
#  ('dNeal,_HeinrichDeutsche_Rhapsodie_No.2,_Op.47_**333791', 3),
#  ('dLiszt,_FranzApparitions,_S.155_**04672', 3),
#  ('dHeller,_StephenPromenades_d%27un_Solitaire,_Op.89_**59557', 3),
#  ('dMozart,_Wolfgang_AmadeusPiano_Sonata_No.9_in_D_major,_K.311**70207', 3),
#  ('dMozart,_Wolfgang_AmadeusPiano_Sonata_No.9_in_D_major,_K.311**00218', 3),
#  ('dDubois,_Th%C3%A9odorePo%C3%A8mes_Virgiliens_**30462', 3),
#  ('dDubois,_Th%C3%A9odorePo%C3%A8mes_Virgiliens_**30456', 3),
#  ('dWood,_Charles16_Preludes_**356716', 3),
#  ('dLyadov,_Anatoly3_Morceaux,_Op.11_**462489', 3),
#  ('dHaberbier,_Ernst%C3%89tudes-po%C3%A9sies,_Opp.53_and_59_**26787', 2),
#  ('dKruckow,_RichardStandard_Graded_Course_of_Studies_for_the_Pianoforte_**345823',
#   2),
#  ('dAhrens,_HarryStandard_Graded_Course_of_Studies_for_the_Pianoforte_**345823',
#   2),
#  ('dBischoff,_HansStandard_Graded_Course_of_Studies_for_the_Pianoforte_**345823',
#   2),
#  ('dOrefice,_Giuseppe_dell%27Biblioteca_d%27oro_**518180', 2),
#  ('dLe_Carpentier,_Adolphe_ClaireStandard_Graded_Course_of_Studies_for_the_Pianoforte_**345823',
#   2),
#  ('dBach,_Johann_Sebastian6_Partitas,_BWV_825-830_**00794', 2),
#  ('dJanke,_GustavStandard_Graded_Course_of_Studies_for_the_Pianoforte_**345823',
#   2),
#  ('dBach,_Johann_SebastianDas_wohltemperierte_Klavier_II,_BWV_870-893_**494709',
#   2),
#  ('dManfroce,_NicolaBiblioteca_d%27oro_**518180', 2),
#  ('dAscher,_JosephDanse_slave,_Op.6_**509054', 2),
#  ('dSachs,_Melchior_ErnstStandard_Graded_Course_of_Studies_for_the_Pianoforte_**345823',
#   2),
#  ('dBesendahl,_Carl6_Tonbilder,_Op.19_**423742', 2),
#  ('dLee_Hatch,_MabelThe_Gay_Butterfly_**518729', 2),
#  ('dFranck,_RichardScherzo,_Op.47_**294225', 2),
#  ('dLee_Hatch,_MabelThe_Gay_Butterfly_**518730', 2),
#  ('dMariani,_AngeloBiblioteca_d%27oro_**518180', 2),
#  ('dBencini,_Pietro_PaoloBiblioteca_d%27oro_**518180', 2),
#  ('dMerkel,_Gustav_Adolf2_Rondos,_Op.154_**367417', 2),
#  ('dNoskowski,_Zygmunt3_Morceaux,_Op.26_**443290', 2),
#  ('dGouin,_PierreDas_wohltemperierte_Klavier_II,_BWV_870-893_**69276', 2),
#  ('dBach,_Johann_SebastianDas_wohltemperierte_Klavier_II,_BWV_870-893_**69276',
#   2),
#  ('dBesendahl,_Carl6_Tonbilder,_Op.19_**423744', 2),
#  ('dCzerny,_CarlBeliebte_Thema_mit_Variationen_im_brillanten_Salon-Styl,_Op.811_**356854',
#   2),
#  ('dBach,_Johann_Sebastian6_Partitas,_BWV_825-830_**62575', 2),
#  ('dBrauer,_FriedrichStandard_Graded_Course_of_Studies_for_the_Pianoforte_**345823',
#   2),
#  ('dLori,_ArcangeloBiblioteca_d%27oro_**518180', 2),
#  ('dWallek-Walewski,_Boles%C5%82awImprovisation_**493690', 2),
#  ('dStrozzi,_BarbaraBiblioteca_d%27oro_**518180', 2),
#  ('dGouin,_PierreDas_wohltemperierte_Klavier_II,_BWV_870-893_**58173', 2),
#  ('dKarg-Elert,_SigfridGradus_ad_Parnassum,_Op.95_**108977', 2),
#  ('dStarke,_FriedrichWiener_Pianoforte_Schule,_Op.108_**388335', 2),
#  ('dCapponi,_FrancescoBiblioteca_d%27oro_**518180', 2),
#  ('dOrda,_NapoleonPolonaise_No.4_%27Odbijany%27_**455380', 2),
#  ('dKontski,_Stanis%C5%82aw_deSouvenir_de_Grudzielec_**448862', 2),
#  ('dDobrzy%C5%84ski,_Ignacy_Feliks3_Nocturnes,_Op.21_**367250', 2),
#  ('dUlrich,_Hugo38_Waltzes,_L%C3%A4ndler_and_Ecossaises,_D.145_**53694', 2),
#  ('dWeber,_Carl_Maria_von6_Variations_sur_l%27air_de_Naga_de_%27Samori%27,_Op.6_**111891',
#   2),
#  ('dSchubert,_Franz6_German_Dances,_D.970_**03142', 2),
#  ('dSchulhoff,_JuliusCarnaval_de_Venise,_Op.22_**130309', 2),
#  ('dTeilman,_ChristianDe_gamles_dans,_Op.53_**284945', 2),
#  ('dSchubert,_Franz38_Waltzes,_L%C3%A4ndler_and_Ecossaises,_D.145_**03160', 2),
#  ('dDraeseke,_Felix2_Fantasiest%C3%BCcke_in_Walzerform,_Op.3_**446255', 2),
#  ('dWest,_George_FrederickBeatrice_**349237', 2),
#  ('dBaylor,_Eugene_W.The_Shirley_Waltzes_**408642', 2),
#  ('dPathe,_Carl_EduardGrazie,_Op.222_**354013', 2),
#  ('dLiszt,_FranzHungarian_Rhapsody_No.2,_S.244**286008', 2),
#  ('dBattmann,_Jacques-LouisLia,_Op.31_**522168', 2),
#  ('dSchubert,_FranzValses_sentimentales,_D.779_**53696', 2),
#  ('dUlrich,_Hugo38_Waltzes,_L%C3%A4ndler_and_Ecossaises,_D.145_**03160', 2),
#  ('dRichards,_BrinleySibylle,_Op.25_**32625', 2),
#  ('dLabitzky,_JosephAurora_Walzer,_Op.34_**109930', 2),
#  ('dUlrich,_HugoValses_sentimentales,_D.779_**53696', 2),
#  ('dOury,_Anna_CarolineRigoletto_Fantasie_**151039', 2),
#  ('dScriabin,_Aleksandr10_Mazurkas,_Op.3_**56694', 2),
#  ('dWeber,_Carl_Maria_vonPiano_Sonata_No.2_in_A-flat_major,_Op.39_**385715',
#   2),
#  ('dGottschalk,_Louis_MoreauMarche_de_Nuit,_Op.17_**125491', 2),
#  ('dPrudent,_%C3%89mileScherzo,_Op.47_**424240', 2),
#  ('dTellier,_Alphonse6_Kinderst%C3%BCcke_**378216', 2),
#  ('dHeins,_CarlUm_die_Linde,_Op.162_**465282', 2),
#  ('dKullak,_TheodorSymphonie_de_Piano,_Op.27_**14446', 2),
#  ('dMirecki,_Maurice_deIkanowa_**333053', 2),
#  ('dSchubert,_Franz38_Waltzes,_L%C3%A4ndler_and_Ecossaises,_D.145_**53694', 2),
#  ('dZaremba,_SigizmundFeu_sacr%C3%A9,_Op.34_**111074', 2),
#  ('dJadassohn,_SalomonImprovisationen,_Op.75_**35582', 2),
#  ('dCui,_C%C3%A9sar25_Preludes,_Op.64_**179622', 2),
#  ('dMozart,_Wolfgang_Amadeus12_Variations_on_%22Ah,_vous_dirai-je_maman%22,_K.265**56885',
#   2),
#  ('dLichner,_HeinrichFenella,_Op.48_**415046', 2),
#  ('dSmith,_SydneyMendelssohn%27s_Scotch_Symphony,_Paraphrase,_Op.101_**54665',
#   2),
#  ('dRichards,_BrinleySibylle,_Op.25_**32624', 2),
#  ('dPlessen,_Friedrich_Leopold_vonTheodoren-Walzer,_Op.40_**62217', 2),
#  ('dGottschalk,_Louis_MoreauThe_Maiden%27s_Blush,_Op.106_**11194', 2),
#  ('dSanderson,_WilfredValsette_**403449', 2),
#  ('dRuiz_Espadero,_Nicol%C3%A1sPiano_Pieces,_Op.1_**410876', 2),
#  ('dAstort_Ribas,_PedroBells_and_Ringles_**508286', 2),
#  ('dMesse,_F.W.Bright_as_Daisies_**206356', 2),
#  ('dSimon,_ErnstLiederstrau%C3%9F,_Op.361_**421332', 2),
#  ('dSchumann,_Robert4_Klavierst%C3%BCcke,_Op.32_**53509', 2),
#  ('p53', 2),
#  ('dBertini,_HenriEpisode_d%27un_bal,_Op.98_**353859', 2),
#  ('dFabian,_J.Bilder_aus_sch%C3%B6ner_Zeit,_Op.7_**96380', 2),
#  ('dLacaze,_J.Tout_Paris,_Op.15_**439432', 2),
#  ('dBachmann,_GeorgesIsabelle_**518092', 2),
#  ('dMoszkowski,_MoritzValse_brillante_**233452', 2),
#  ('dComettant,_OscarHeures_d%27harmonie_**373187', 2),
#  ('dLowthian,_CarolineVenetia_Waltz_**288570', 2),
#  ('dKirchner,_Theodor4_Notturnos,_Op.28_**08116', 2),
#  ('dStarke,_FriedrichWiener_Pianoforte_Schule,_Op.108_**495095', 2),
#  ('dAbt,_FranzDie_Bonvivants,_Op.20_**315916', 2),
#  ('dSmith,_SydneyFantaisie_Brillante_on_%27Fra_Diavolo%27,_Op.67_**54639', 2),
#  ('dMendelssohn,_FelixVariations_s%C3%A9rieuses,_Op.54_**52240', 2),
#  ('dMandyczewski,_EusebiusValses_sentimentales,_D.779_**53696', 2),
#  ('dBarili,_AlfredoValse-Caprice,_Op.2_**81302', 2),
#  ('dC%C5%93d%C3%A8s,_AugusteValse_des_amours_**259789', 2),
#  ('dAletter,_Wilhelm6_Kinderst%C3%BCcke_**378216', 2),
#  ('dMaylath,_HenryTwilight_**381641', 2),
#  ('dWolff,_%C3%89douardLe_tournoi,_Op.151_**184289', 2),
#  ('dGlazunov,_AleksandrGrande_valse_de_concert,_Op.41_**02711', 2),
#  ('dStrack,_LouisWhat_You_Will_**252006', 2),
#  ('dGottschalk,_Louis_MoreauThe_Dying_Poet,_Op.110_**260493', 2),
#  ('dSchumann,_Robert4_Klavierst%C3%BCcke,_Op.32_**53510', 2),
#  ('dScriabin,_Aleksandr10_Mazurkas,_Op.3_**76946', 2),
#  ('dStrelezki,_AntonL%27Aurore_**80475', 2),
#  ('dBeck,_James_N.The_Falling_Leaf_**411445', 2),
#  ('dKafka,_Ernest2_Valses_de_salon,_Op.10_**467739', 2),
#  ('dSchreiner,_Hermann_L.Savannah_Park_Waltzes_**492271', 2),
#  ('dCzerny,_CarlDie_Schule_des_Vortrags_und_der_Verzierungen,_Op.575_**363413',
#   2),
#  ('dHofmann,_J%C3%B3zefCharakterskizzen,_Op.40_**02584', 2),
#  ('dMaylath,_HenryElegie,_Op.304_**113683', 2),
#  ('dWollenhaupt,_Hermann_AdolfThe_Lover%27s_Letter_Box,_Op.44_**427678', 2),
#  ('dEnckhausen,_Heinrich_FriedrichDes_Pianoforte-Spielers_erste_Studien,_Op.63_**142946',
#   2),
#  ('dWaldteufel,_L%C3%A9onAmazilia_**257194', 2),
#  ('dHummel,_Johann_NepomukPiano_Sonata_No.2,_Op.13_**72450', 2),
#  ('dWittmann,_RobertAngenehme_und_leichte_Unterhaltungen_am_Pianoforte_**468356',
#   2),
#  ('dBachmann,_GeorgesIsabelle_**518093', 2),
#  ('dKalkbrenner,_Friedrich_WilhelmIntroduction_et_Rondino,_Op.78_**176125', 2),
#  ('dSchubert,_Franz6_German_Dances,_D.970_**53757', 2),
#  ('dSchmoll,_AntonMelody_Pictures_for_Study_and_Recreation_**321751', 2),
#  ('dHeller,_StephenL%27art_de_phraser,_Op.16_**266306', 2),
#  ('dKnuth,_J%C3%BCrgen12_Variations_on_%22Ah,_vous_dirai-je_maman%22,_K.265**56885',
#   2),
#  ('dLange,_GustavLa_Reine_du_bal,_Op.16_**297931', 2),
#  ('dHummel,_Johann_NepomukPiano_Sonata_No.2,_Op.13_**72449', 2),
#  ('dGoria,_Alexandre_%C3%89douardMazurka_No.1,_Op.5_**11186', 2),
#  ('dRubinstein,_Anton2_M%C3%A9lodies,_Op.3_**446911', 2),
#  ('dFaur%C3%A9,_GabrielNocturne_No.4,_Op.36_**00555', 2),
#  ('dChesneau,_CarlLa_fanfare,_Op.12_**101634', 2),
#  ('dBeethoven,_Ludwig_vanPiano_Sonata_No.16,_Op.31_No.1_**419637', 2),
#  ('dGottschalk,_Louis_MoreauThe_Dying_Poet,_Op.110_**378068', 2),
#  ('dScriabin,_Aleksandr10_Mazurkas,_Op.3_**76945', 2),
#  ('dWallis,_LouisDreaming_Beauty_**203653', 2),
#  ('dBerger,_WilhelmPiano_Sonata,_Op.76_**81382', 2),
#  ('dKlein,_JulesCerises_Pompadour_**266808', 2),
#  ('dBeck,_James_N.Fanny%27s_Dream_Waltz_**411854', 2),
#  ('dThalberg,_SigismondMarche_fun%C3%A8bre,_Op.59_**07080', 2),
#  ('dBohm,_CarlSalon-Kompositionen,_Op.327_**518224', 2),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricBolero,_Op.19_**114991', 2),
#  ('dThayer,_Herbert_Wells6_Kinderst%C3%BCcke_**378216', 2),
#  ('dBaylor,_Eugene_W.The_Shirley_Waltzes_**408641', 2),
#  ('dChouquet,_LouiseSerenade_for_the_Left_Hand_**30147', 2),
#  ('dMorandi,_GiovanniRaccolta_di_sonate_per_gli_organi_moderni_No.5_**106711',
#   2),
#  ('dMoscheles,_IgnazFantaisie_Dramatique,_Op.86b_**08246', 2),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricGrande_valse_brillante,_Op.18_**34465', 2),
#  ('dPessard,_%C3%89mile20_Pi%C3%A8ces_nouvelles,_Op.26_**112874', 2),
#  ('dSchumann,_RobertHumoreske,_Op.20_**51546', 2),
#  ('dBerg%C3%A9,_Ir%C3%A9n%C3%A9eCapriccio_**489351', 2),
#  ('dAlkan,_Charles-ValentinEsquisses,_Op.63_**519846', 2),
#  ('dHerz,_HenriVariations_brillantes_on_Bellini%27s_%27La_sonnambula%27,_Op.105_**12891',
#   2),
#  ('dStrelezki,_AntonPiano_Pieces,_Op.32_**518514', 2),
#  ('dKontski,_Anton_de3_M%C3%A9ditations,_Op.42_**448701', 2),
#  ('dKontski,_Anton_deSouvenir_de_Carlsbad,_Op.151_**447547', 2),
#  ('dCazaneuve,_%C3%89douardVoil%C3%A0_le_plaisir,_Mesdames!_**326142', 2),
#  ('dPfeiffer,_Georges_JeanMazurka_de_salon_No.5,_Op.35_**255988', 2),
#  ('dReinhold,_Hugo12_Impressionen,_Op.68_**388850', 2),
#  ('dLundberg,_LennartPolonaise,_Op.57_**433886', 2),
#  ('dNeustedt,_CharlesFantaisie-transcription_sur_%27La_sonnambula%27,_Op.73_**376984',
#   2),
#  ('dCzerny,_CarlVariations_brillantes_sur_%27Robert_le_diable%27,_Op.332_**506867',
#   2),
#  ('dGottschalk,_Louis_MoreauPolonia,_Op.43_**121765', 2),
#  ('dDella-Tolla,_AntoineLa_Gran_Via_**486361', 2),
#  ('dButler,_LeonardAt_Nightfall_**316280', 2),
#  ('dLiszt,_FranzApparitions,_S.155_**55553', 2),
#  ('dLeybach,_Ignace_Xavier_JosephMagali,_Op.83_**371440', 2),
#  ('dJensen,_AdolfJagdscene,_Op.15_**152268', 2),
#  ('dLavall%C3%A9e,_CalixaLe_papillon_**20167', 2),
#  ('dWarren,_George_WilliamGeneral_Burnside%27s_Grand_Triumphal_March_**401384',
#   2),
#  ('dLiszt,_FranzApparitions,_S.155_**13292', 2),
#  ('dVierne,_LouisSuite_bourguignonne,_Op.17_**15815', 2),
#  ('dVierne,_LouisSuite_bourguignonne,_Op.17_**04435', 2),
#  ('dR%C3%B6ntgen,_JuliusDolce_far_niente,_Op.60_**103577', 2),
#  ('dNoskowski,_ZygmuntPetits_Rayons,_Op.39_**504607', 2),
#  ('dThalberg,_SigismondSouvenir_de_Vienne,_Op.4_**29773', 2),
#  ('dStrauss_Sr.,_JohannTausendsapperment_Walzer,_Op.61_**175587', 2),
#  ('dBenoit,_PeterPiano_Sonata,_Op.34_**408012', 2),
#  ('dBrzezi%C5%84ski,_FranciszekStimmungsbilder_in_Variationenform,_Op.3_**74583',
#   2),
#  ('dLiszt,_FranzApparitions,_S.155_**13333', 2),
#  ('dTedesco,_IgnazGrande_Valse_brillante_No.3,_Op.62_**446444', 2),
#  ('dLiebling,_EmilFlorence,_Op.12_**190739', 2),
#  ('dL%C3%B8venskiold,_Hannah5_Kompositioner_for_Klaver_**272702', 2),
#  ('dBellak,_JamesKleber%27s_Rainbow_Schottisch,_Op.546_**194751', 2),
#  ('dLiszt,_Franz12_Lieder_von_Franz_Schubert,_S.558_**06392', 2),
#  ('dCzerny,_CarlThe_Art_of_Preluding,_Op.300_**255178', 2),
#  ('dGonz%C3%A1lez_del_Valle,_AnselmoFantas%C3%ADa_sobre_motivos_de_la_%C3%B3pera_%27Fausto%27,_Op.15_**411610',
#   2),
#  ('dBach,_Johann_SebastianDas_wohltemperierte_Klavier_II,_BWV_870-893_**62105',
#   2),
#  ('dCzerny,_CarlFantaisie_brillante_sur_des_airs_chinois,_Op.724_**356845', 2),
#  ('dGouin,_PierreDas_wohltemperierte_Klavier_II,_BWV_870-893_**62105', 2),
#  ('dLiszt,_Franz12_Lieder_von_Franz_Schubert,_S.558_**516478', 2),
#  ('dMoscheles,_Ignaz12_Etudes,_Op.95_**03574', 2),
#  ('dClementi,_Muzio3_Piano_Sonatas,_Op.23_**511104', 2),
#  ('dLazarus,_Gustav9_Leichte_lyrische_St%C3%BCcke,_Op.137_**23849', 2),
#  ('dWeyse,_Christoph_Ernst_Friedrich8_Etudes,_Op.51_**33600', 2),
#  ('dPeterson-Berger,_WilhelmTonm%C3%A5lningar,_Op.13_**434830', 2),
#  ('dKarg-Elert,_Sigfrid3_Pastels,_Op.92_**386720', 2),
#  ('dGouin,_PierrePi%C3%A8ces_d%27orgue_attribu%C3%A9es_%C3%A0_Leb%C3%A8gue_**03932',
#   2),
#  ('dBraga,_HenriqueRegrets_**398646', 2),
#  ('dAnduaga,_Eduardo_H._deLa_torre_Eiffel_**511298', 2),
#  ('dKalkbrenner,_Friedrich_Wilhelm3_Piano_Sonatas,_Op.4_**09056', 2),
#  ('dLiszt,_FranzAlbum_d%27un_voyageur,_S.156_**31081', 2),
#  ('dDubois,_Th%C3%A9odore12_Pi%C3%A8ces_Nouvelles_pour_Orgue_**08725', 2),
#  ('dJentsch,_Max3_Mazurkas,_Op.22_**58545', 2),
#  ('dThalberg,_Sigismond3_Nocturnes,_Op.21_**07060', 2),
#  ('dBarker,_George_ArthurFremont%27s_Battle_March_**320107', 2),
#  ('dWagner,_FerdinandGalop_martial_**402456', 2),
#  ('dLemmens,_Jacques-Nicolas3_Organ_Sonatas_**386685', 2),
#  ('dGouin,_Pierre12_Pi%C3%A8ces_Nouvelles_pour_Orgue_**08725', 2),
#  ('dBeethoven,_Ludwig_vanPiano_Sonata_No.22,_Op.54_**69584', 2),
#  ('dPavlov,_EvgenyValse_%27To_the_Memory_of_Scriabin%27_**359422', 2),
#  ('dCzerny,_CarlStudien_zur_praktischen_Kenntniss_aller_Accorde_des_Generalbasses,_Op.838_**365216',
#   2),
#  ('dBiehl,_AlbertVergn%C3%BCgte_Ferien!,_Op.106_**94682', 2),
#  ('dH%C3%BCnten,_Fran%C3%A7oisLes_jeunes_compagnes,_Op.95_**253822', 2),
#  ('dGabriel,_Charles_HutchinsonMonopoly_**197271', 2),
#  ('dBatiste,_Edouard50_Pi%C3%A8ces_d%27orgue,_Opp.24,_25_**17504', 2),
#  ('dVorontsova,_MariyaAlbum_of_Favorite_Songs_**387744', 2),
#  ('dKlimovsky,_YevgenyAlbum_of_Favorite_Songs_**387744', 2),
#  ('dBechgaard,_Julius4_Fantasiestykker,_Op.2_**415656', 2),
#  ('dLange,_GustavWanda,_Op.25_**297932', 2),
#  ('dShashina,_YelizavetaAlbum_of_Favorite_Songs_**387744', 2),
#  ('dHuenerbein,_CharlesThe_Plateau_Valse_**104931', 2),
#  ('dLange,_GustavIm_Kloster,_Op.345_**23304', 2),
#  ('dBulakhov,_PyotrAlbum_of_Favorite_Songs_**387744', 2),
#  ('dPashkov,_NikolayAlbum_of_Favorite_Songs_**387744', 2),
#  ('dDerviz,_NikolayAlbum_of_Favorite_Songs_**387744', 2),
#  ('dStrohl,_RitaTh%C3%A8me_et_variations,_Op.40_**336413', 2),
#  ('dMendelssohn,_Felix6_Preludes_and_Fugues,_Op.35_**53958', 2),
#  ('dJuon,_Paul10_Esquisses,_Op.55_**237247', 2),
#  ('dGouin,_Pierre6_Preludes_and_Fugues,_Op.35_**53958', 2),
#  ('dReichel,_C.A.6_Polonoises,_Op.3_**85179', 2),
#  ('dWieniawski,_J%C3%B3zef2_Morceaux_de_concert,_Opp.9_%26_10_**444946', 2),
#  ('dSchubert,_Franz38_Waltzes,_L%C3%A4ndler_and_Ecossaises,_D.145_**418086',
#   2),
#  ('dUlrich,_Hugo38_Waltzes,_L%C3%A4ndler_and_Ecossaises,_D.145_**418086', 2),
#  ('dDe_Anguera,_FernandoHarvard_grande_valse_de_salon_**507637', 2),
#  ('dTeilman,_Christian2_Mazurkas,_Op.57_**281063', 2),
#  ('dM%C3%A9reaux,_Jean-Am%C3%A9d%C3%A9e_Lefroid_deGrande_valse_pour_piano,_Op.46_**341379',
#   2),
#  ('dZhilin,_AlekseyAlbum_of_Favorite_Songs_**387744', 2),
#  ('dWielhorski,_Micha%C5%82Album_of_Favorite_Songs_**387744', 2),
#  ('dHahn,_ReynaldoPremi%C3%A8res_valses_**03225', 2),
#  ('dUlrich,_Hugo38_Waltzes,_L%C3%A4ndler_and_Ecossaises,_D.145_**37831', 2),
#  ('dHartmann,_Johan_Peter_Emilius6_Character_Pieces,_Op.50_**438524', 2),
#  ('dKlein,_JulesRadis_roses%3F_**255435', 2),
#  ('dBalmer,_CharlesConcert_Hall_Cotillion_**357317', 2),
#  ('dKochubey,_YelizavetaAlbum_of_Favorite_Songs_**387744', 2),
#  ('dSchubert,_Franz38_Waltzes,_L%C3%A4ndler_and_Ecossaises,_D.145_**37831', 2),
#  ('dJans,_Anselme4_Petits_morceaux_r%C3%A9cr%C3%A9atifs,_Op.19_**518333', 2),
#  ('dBo%C3%ABly,_Alexandre-Pierre-Fran%C3%A7ois30_Caprices,_Op.2_**400514', 2),
#  ('dMicha%C5%82owski,_AleksanderMazurka,_Op.31_No.1_**357127', 2),
#  ('dMicha%C5%82owski,_AleksanderMazurka,_Op.31_No.1_**505398', 2),
#  ('dNiewiadomski,_Stanis%C5%82awPolonaise_et_Krakowiak,_Op.31_**443234', 2),
#  ('dGreulich,_AdolfLe_mus%C3%A9e_des_pianistes_**173187', 2),
#  ('dLiszt,_FranzSoir%C3%A9es_de_Vienne,_S.427_**67694', 2),
#  ('dMariani,_AngeloBiblioteca_d%27oro_**18488', 2),
#  ('dLeonhard,_Julius_EmilPiano_Sonata_quasi_Fantasia,_Op.5_**413583', 2),
#  ('dCramer,_HenriLa_Smahla_**101968', 2),
#  ('dManfroce,_NicolaBiblioteca_d%27oro_**18488', 2),
#  ('dBertini,_Henri24_Etudes,_Op.29_**08601', 2),
#  ('dKochubey,_YelizavetaAlbum_of_Favorite_Songs_**387739', 2),
#  ('dBeethoven,_Ludwig_vanPolonaise_in_C_major,_Op.89_**05148', 2),
#  ('dFolk_Songs,_HungarianWiener_Pfennig-Magazin_**365664', 2),
#  ('dBulakhov,_PyotrAlbum_of_Favorite_Songs_**387739', 2),
#  ('dGottschalk,_Louis_MoreauLe_Bananier,_Op.5_**24348', 2),
#  ('dSchulhoff,_JuliusGrande_valse_brillante,_Op.6_**28645', 2),
#  ('dShashina,_YelizavetaAlbum_of_Favorite_Songs_**387739', 2),
#  ('dHorzalka,_JohannWiener_Pfennig-Magazin_**365664', 2),
#  ('dSchumann,_RobertEtudes_after_Paganini_Caprices,_Op.3_**54919', 2),
#  ('dArban,_Jean-BaptisteSouvenir_de_Lisbonne_**323400', 2),
#  ('dAndr%C3%A9e,_ElfridaPiano_Sonata,_Op.3_**71789', 2),
#  ('dSchumann,_RobertAbegg_Variations,_Op.1_**77076', 2),
#  ('dSmith,_SydneyFeu_de_joie,_Op.28_**98685', 2),
#  ('dComellas,_Jos%C3%A9Vienne,_Op.4_**319374', 2),
#  ('dKronke,_Emil4_Deutsche_T%C3%A4nze,_Op.65_**51306', 2),
#  ('dDe_Anguera,_FernandoVictorious_Grand_March_**507650', 2),
#  ('dJoteyko,_TadeuszMiniatures,_Op.23_**501680', 2),
#  ('dHennes,_AloysBadeerinnerungen,_Op.262_**383826', 2),
#  ('dTaigner,_FerdinandWiener_Pfennig-Magazin_**365664', 2),
#  ('dBosissioJe_m%27en_moque_**502089', 2),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricFantaisie,_Op.49_**249125', 2),
#  ('dHeller,_Stephen25_Etudes,_Op.47_**462083', 2),
#  ('dNeupert,_Edmund12_Etudes,_Op.19_**310295', 2),
#  ('dKeil,_AlfredoImpressions_poetiques,_Op.12_**110392', 2),
#  ('dBallard,_L._W.Pleasure_Waltz_**356570', 2),
#  ('dScharwenka,_Philipp3_Humoresken,_Op.31_**192272', 2),
#  ('dSchumann,_RobertPiano_Sonata_No.3,_Op.14_**289790', 2),
#  ('dKlimovsky,_YevgenyAlbum_of_Favorite_Songs_**387739', 2),
#  ('dNoskowski,_ZygmuntKrakowiaki,_Op.25_**446184', 2),
#  ('dCui,_C%C3%A9sar3_Mouvements_de_valse,_Op.41_**24930', 2),
#  ('dCzerny,_Carl3_Grand_Marches,_Op.79_**73258', 2),
#  ('dSchumann,_RobertImpromptus,_Op.5_**289904', 2),
#  ('dVolckmar,_Wilhelm_Valentin8_Festspiele,_Op.368_**250443', 2),
#  ('dStrakosch,_MauriceFlirtation_**192089', 2),
#  ('dSt%C3%B6ber,_KarlWiener_Pfennig-Magazin_**365664', 2),
#  ('dDerviz,_NikolayAlbum_of_Favorite_Songs_**387739', 2),
#  ('dPaufler,_Christian_HeinrichAlbum_of_Favorite_Songs_**387739', 2),
#  ('dMascheroni,_EdoardoBiblioteca_d%27oro_**18488', 2),
#  ('dDonaurov,_SergeyAlbum_of_Favorite_Songs_**387739', 2),
#  ('dK%C3%A9ler,_B%C3%A9la%C3%9Cst%C3%B6k%C3%B6s-Cs%C3%A1rd%C3%A1s,_Op.49_**315701',
#   2),
#  ('dWielhorski,_Micha%C5%82Album_of_Favorite_Songs_**387739', 2),
#  ('dPachulski,_HenrykPiano_Sonata_No.1,_Op.10_**505714', 2),
#  ('dColberg,_PaulConzert_Walzer_**310325', 2),
#  ('dVorontsova,_MariyaAlbum_of_Favorite_Songs_**387739', 2),
#  ('dBencini,_Pietro_PaoloBiblioteca_d%27oro_**18488', 2),
#  ('dLori,_ArcangeloBiblioteca_d%27oro_**18488', 2),
#  ('dNoskowski,_Zygmunt8_Cracoviennes,_Op.2_**446174', 2),
#  ('dChopin,_Fr%C3%A9d%C3%A9ric%C3%89tudes,_Op.25_**102463', 2),
#  ('dLyapunov,_SergeyPiano_Sonata,_Op.27_**01643', 2),
#  ('dCzerny,_CarlL%27Infatigable,_Op.779_**359647', 2),
#  ('dMayer,_CharlesGrandes_variations_brillantes_sur_l%27Air_Russe_national,_Op.32_**357241',
#   2),
#  ('dGottschalk,_Louis_MoreauMiserere_du_Trovatore,_Op.52_**378055', 2),
#  ('dAbbot,_John_M.L%27Esperance_**299811', 2),
#  ('dShcherbachyov,_NikolayMosa%C3%AFque,_Op.15_**85343', 2),
#  ('dDussek,_Jan_LadislavPiano_Sonata_No.18,_Op.44_**297103', 2),
#  ('dMarmontel,_Antoine_Fran%C3%A7ois50_Etudes_de_Salon,_Op.108_**09305', 2),
#  ('dLoret,_Cl%C3%A9ment12_Morceaux_pour_harmonium_**319445', 2),
#  ('dCzerny,_Carl3_Grand_Allegros,_Op.75_**500362', 2),
#  ('dTeilman,_CarlValse_Rose_**295054', 2),
#  ('dBaylor,_Eugene_W.The_Shirley_Waltzes_**408643', 2),
#  ('dCzerny,_Carl3_Grand_Allegros,_Op.75_**100084', 2),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricRondo_in_E-flat_major,_Op.16_**87700', 2),
#  ('dBart%C3%B3k,_B%C3%A9laRhapsody_for_Piano,_Sz.26_**00855', 2),
#  ('dSinding,_Christian5_Etudes,_Op.58_**07210', 2),
#  ('dCappelen,_ChristianMazurka-Caprice,_Op.15_**282981', 2),
#  ('dMoszkowski,_Moritz6_Klavierst%C3%BCcke,_Op.15_**110913', 2),
#  ('dWagner,_CarlSouvenir_de_Chopin_**173464', 2),
#  ('dGarstin,_Harold5_Musical_Impressions_**321007', 2),
#  ('dS%C3%A9verac,_D%C3%A9odat_deCerda%C3%B1a_**06080', 2),
#  ('dBlumenfeld,_FelixSuite_Polonaise_No.2,_Op.31_**07192', 2),
#  ('dCappelen,_ChristianMazurka-Caprice,_Op.15_**281678', 2),
#  ('dBach,_Johann_Sebastian6_Partitas,_BWV_825-830_**76512', 2),
#  ('dGarstin,_Harold5_Musical_Impressions_**320524', 2),
#  ('dM%C3%A9reaux,_Jean-Am%C3%A9d%C3%A9e_Lefroid_deGrande_valse_pour_piano,_Op.46_**336635',
#   2),
#  ('dDunn,_Marion_AustinA_Christmas_Idyll_**348706', 2),
#  ('dBeecke,_Ignaz_vonPi%C3%A8ces_de_Clavecin_**340672', 2),
#  ('dScharwenka,_Xaver4_Polish_Dances,_Op.58_**07392', 2),
#  ('dZar%C4%99bski,_JuliuszImpromptu-Caprice,_Op.14_**504923', 2),
#  ('dH%C3%A4gg,_Jacob_Adolf9_Character_Pieces,_Op.8_**433467', 2),
#  ('dBattmann,_Jacques-LouisPiano_Sonatine,_Op.142_**266478', 2),
#  ('dNorman,_LudvigBarnens_danser_och_lekar,_Op.47_**434588', 2),
#  ('dZar%C4%99bski,_JuliuszImpromptu-Caprice,_Op.14_**08640', 2),
#  ('dJadin,_Hyacinthe3_Piano_Sonatas,_Op.5_**34097', 2),
#  ('dWeyse,_Christoph_Ernst_FriedrichPiano_Sonata_No.7_in_A_minor_**89950', 2),
#  ('dBalmer,_CharlesBavarian_Schottisch_with_Variations_**76167', 2),
#  ('dMoszkowski,_MoritzCaprice,_Op.4_**06834', 2),
#  ('dGaleotti,_CesareValse-Caprice,_Op.64_**46258', 2),
#  ('dRuthardt,_Adolf6_Vortragsst%C3%BCcke,_Op.51_**353158', 2),
#  ('dMacDowell,_EdwardSecond_Modern_Suite,_Op.14_**266400', 2),
#  ('dMaylath,_HenryLe_R%C3%A9pertoire_pour_les_petites_mains,_Op.56_**380814',
#   2),
#  ('dMacDowell,_EdwardSecond_Modern_Suite,_Op.14_**179128', 2),
#  ('dAlkan,_Charles-ValentinVariations_%C3%A0_la_vielle_**03084', 2),
#  ('dDana,_RuthCollection_of_Liszt_editions,_Volume_1_**14247', 2),
#  ('dNoskowski,_Zygmunt3_Morceaux,_Op.26_**389420', 2),
#  ('dSpindler,_FritzBl%C3%A4tter_und_Bl%C3%BCten,_Op.123_**521114', 2),
#  ('dBrounoff,_PlatonIn_the_Flower_Garden_**209615', 2),
#  ('dDvo%C5%99%C3%A1k,_Anton%C3%ADnPoetic_Tone_Pictures,_Op.85_**01659', 2),
#  ('dGouin,_PierrePremier_livre_de_pi%C3%A8ces_de_clavecin_**107264', 2),
#  ('dNoskowski,_ZygmuntAquarelles,_Op.20_**442637', 2),
#  ('dSpindler,_FritzBl%C3%A4tter_und_Bl%C3%BCten,_Op.123_**521115', 2),
#  ('dWidor,_Charles-MarieValses,_Op.71_**206472', 2),
#  ('dKalkbrenner,_Friedrich_WilhelmGrande_sonate_brillante,_Op.177_**09081', 2),
#  ('dCzerny,_Carl14_%C3%89cossaises_brillantes,_Op.174_**366498', 2),
#  ('dMichaelis,_AlfredNeue_Praktische_Schule_f%C3%BCr_das_Harmonium,_Op.14_**519337',
#   2),
#  ('dKalkbrenner,_Friedrich_WilhelmRondo,_Op.52_**378470', 2),
#  ('dSmith,_SydneyGrande_Fantaisie_de_Concert_on_%27Der_Freischuetz%27,_Op.16_**34993',
#   2),
#  ('dSchiwy,_JuliusAu_Chateau_Miechowitz,_Op.10_**416722', 2),
#  ('dBalmer,_CharlesI%27ll_Roam_the_Dewy_Bowers_**76164', 2),
#  ('dWagner,_MaxRauschgold_**498714', 2),
#  ('dKuhlau,_FriedrichPiano_Sonata,_Op.4_**25416', 2),
#  ('dBaylor,_Eugene_W.Black_Diamond_Polka_Mazurka_**407783', 2),
#  ('dFranck,_C%C3%A9sarGrande_pi%C3%A8ce_symphonique,_Op.17_**03781', 2),
#  ('dFranck,_C%C3%A9sarGrande_pi%C3%A8ce_symphonique,_Op.17_**490385', 2),
#  ('dWalther,_Johann_GottfriedS%C3%A4mtliche_freie_Orgelwerke_**21667', 2),
#  ('dGouin,_PierreGrande_pi%C3%A8ce_symphonique,_Op.17_**490385', 2),
#  ('dCasella,_AlfredoA_la_Mani%C3%A8re_de...,_Op.17_**10564', 2),
#  ('dGouin,_PierreGrande_pi%C3%A8ce_symphonique,_Op.17_**03781', 2),
#  ('dHeller,_StephenFreisch%C3%BCtz_Studien,_Op.127_**83858', 2),
#  ('dCerruti,_Giuseppe12_Sonate_per_i_principali_Registri_**76134', 2),
#  ('dMathews,_William_Smythe_BabcockStandard_Graded_Course_of_Studies_for_the_Pianoforte_**345825',
#   2),
#  ('dBischoff,_HansStandard_Graded_Course_of_Studies_for_the_Pianoforte_**345825',
#   2),
#  ('dMathias,_Georges3_Morceaux_de_concert,_Opp.38-40_**331138', 2),
#  ('dLe_Carpentier,_Adolphe_ClaireStandard_Graded_Course_of_Studies_for_the_Pianoforte_**345825',
#   2),
#  ('dBrauer,_FriedrichStandard_Graded_Course_of_Studies_for_the_Pianoforte_**345825',
#   2),
#  ('dSachs,_Melchior_ErnstStandard_Graded_Course_of_Studies_for_the_Pianoforte_**345825',
#   2),
#  ('dGheyn,_Matthias_van_den6_Divertimenti_**129757', 2),
#  ('dDuvernoy,_Jean-BaptisteAu_clair_de_la_lune,_Op.296_**421917', 2),
#  ('dJanke,_GustavStandard_Graded_Course_of_Studies_for_the_Pianoforte_**345825',
#   2),
#  ('dAhrens,_HarryStandard_Graded_Course_of_Studies_for_the_Pianoforte_**345825',
#   2),
#  ('dKruckow,_RichardStandard_Graded_Course_of_Studies_for_the_Pianoforte_**345825',
#   2),
#  ('dHuber,_Hans10_Grosse_Et%C3%BCden,_Op.9_**311146', 2),
#  ('dBalmer,_CharlesI%27ll_Roam_the_Dewy_Bowers_**362617', 2),
#  ('dRutini,_Giovanni_MarcoSonata_in_C_major_**90380', 2),
#  ('dMathias,_Georges3_Morceaux_de_concert,_Opp.38-40_**517977', 2),
#  ('dWilson,_Grenville_DeanMaterial_for_Early_Piano_Instruction_**82025', 2),
#  ('dLacombe,_LouisValse_No.3,_Op.58_**399952', 2),
#  ('dKleber,_HenryThe_Rainbow_Schottisch_**508528', 2),
#  ('dBattmann,_Jacques-Louis72_Pieces_for_Organ,_Op.60_**38995', 2),
#  ('dDavid,_AdolpheTarentelle,_Op.40_**264851', 2),
#  ('dLange,_Gustav4_Ungarische_T%C3%A4nze,_Op.266_**47924', 2),
#  ('dKosenko,_Viktor24_Children%27s_Pieces,_Op.25_**396354', 2),
#  ('dHenselt,_Adolf_von12_%C3%89tudes_caract%C3%A9ristiques,_Op.2_**288374', 2),
#  ('dHenselt,_Adolf_von12_%C3%89tudes_caract%C3%A9ristiques,_Op.2_**03229', 2),
#  ('dLoeschhorn,_Albert30_Melodische_Et%C3%BCden,_Op.52_**113427', 2),
#  ('dHenselt,_Adolf_von12_%C3%89tudes_caract%C3%A9ristiques,_Op.2_**58727', 2),
#  ('dM%C3%BCller,_Julius_E.Baltimore_Museum_**260985', 2),
#  ('dChandelier,_AlbertJoyeux_Picards_**54131', 2),
#  ('dLachner,_Franz_PaulRondeau_brillant,_Op.17_**470593', 2),
#  ('dLachner,_Franz_PaulRondeau_brillant,_Op.17_**113760', 2),
#  ('dGouin,_PierreChorale_Preludes,_BWV_714-765_**05821', 2),
#  ('dJuon,_PaulMoments_lyriques,_Op.56_**110238', 2),
#  ('dRaff,_JoachimSuite_No.6_for_Piano,_Op.163_**07286', 2),
#  ('dD%C3%B6hler,_TheodorFantaisie_sur_des_motifs_favoris_de_%27Robert_le_diable%27,_Op.6_**290130',
#   2),
#  ('dWheeldon,_Herbert_ArthurEvening_Chimes_**76562', 2),
#  ('dClementi,_Muzio6_Piano_Sonatinas,_Op.36_**29868', 2),
#  ('dLitolff,_Henry_CharlesImpressions_de_voyage,_Op.117_**289170', 2),
#  ('dGouin,_PierrePi%C3%A8ces_d%E2%80%99orgue_sur_les_8_tons_**515706', 2),
#  ('dGodowsky,_LeopoldMoto_perpetuo_**13184', 2),
#  ('dJensen,_AdolfLieder_und_T%C3%A4nze,_Op.33_**121062', 2),
#  ('dRies,_Ferdinand3_Sets_of_Variations,_Op.82_**452599', 2),
#  ('dClementi,_Muzio6_Piano_Sonatinas,_Op.36_**63976', 2),
#  ('dMozart,_Wolfgang_Amadeus9_Variations_on_a_Minuet_by_Duport,_K.573_**25460',
#   2),
#  ('dMozart,_Wolfgang_Amadeus9_Variations_on_a_Minuet_by_Duport,_K.573_**56893',
#   2),
#  ('dMaichelbeck,_Franz_Anton8_Keyboard_Sonatas,_Op.1_**492712', 2),
#  ('dClementi,_Muzio6_Piano_Sonatinas,_Op.36_**63977', 2),
#  ('dFerrer,_Jos%C3%A9La_Inquieta_**448474', 2),
#  ('dSchumann,_RobertAllegro,_Op.8_**00708', 2),
#  ('dNoskowski,_Zygmunt3_Morceaux,_Op.26_**446185', 2),
#  ('dEvers,_CarlPiano_Sonata,_Op.12_**385436', 2),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricMazurkas,_Op.50_**96503', 2),
#  ('dDecq,_AdhemarMozart_improvisateur,_Op.71_**265487', 2),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricMazurkas,_Op.50_**111845', 2),
#  ('dKirchner,_TheodorIm_Zwielicht,_Op.31_**366275', 2),
#  ('dArban,_Jean-Baptiste2_Polkas-mazurkas_**514842', 2),
#  ('dKirchner,_TheodorIm_Zwielicht,_Op.31_**07517', 2),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricMazurkas,_Op.50_**113869', 2),
#  ('dBordes,_Charles4_Fantaisies_rythmiques_**89848', 2),
#  ('dOesten,_TheodoreFr%C3%BChlingsknospen,_Op.173_**209995', 2),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricMazurkas,_Op.50_**142722', 2),
#  ('dMullen,_Alfred_FredericIn_Arcady_**458389', 2),
#  ('dNeupert,_Edmund4_Piano_Pieces_**89218', 2),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricMazurkas,_Op.50_**399497', 2),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricMazurkas,_Op.50_**00449', 2),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricMazurkas,_Op.50_**96504', 2),
#  ('dPachulski,_HenrykPiano_Sonata_No.1,_Op.10_**130823', 2),
#  ('dWielhorski,_J%C3%B3zef2_Bagatelles,_Op.41_**446224', 2),
#  ('dChadwick,_George_Whitefield5_Pieces_**11030', 2),
#  ('dMorena,_CamilloTortajada,_Op.10_**421275', 2),
#  ('dJensen,_AdolfRomantische_Studien,_Op.8_**06063', 2),
#  ('dJuon,_Paul10_Esquisses,_Op.55_**71204', 2),
#  ('dMasarnau,_Santiago_deL%27innocente,_Op.13_**446069', 2),
#  ('dLemaigre,_Edmond12_Pieces_for_the_Organ_**10274', 2),
#  ('dKnuth,_J%C3%BCrgenPi%C3%A8ces_d%27orgue,_Livre_1_**03789', 2),
#  ('dIlyinsky,_AleksandrLa_journ%C3%A9e_d%27une_petite_fille,_Op.19_**11961',
#   1),
#  ('dKnuth,_J%C3%BCrgenLivre_d%27orgue_**03766', 1),
#  ('dGodowsky,_LeopoldWalzermasken_**11029', 1),
#  ('dSapelnikov,_Vasily3_Pieces,_Op.5_**114610', 1),
#  ('dBridge,_FrankA_Fairy_Tale,_H.128_**11004', 1),
#  ('dKosenko,_Viktor2_Concert_Valses,_Op.22_**396362', 1),
#  ('dClementi,_Muzio3_Piano_Sonatas,_Op.33_**63300', 1),
#  ('dClementi,_Muzio3_Piano_Sonatas,_Op.40_**400298', 1),
#  ('dBach,_Johann_SebastianDas_wohltemperierte_Klavier_II,_BWV_870-893_**36337',
#   1),
#  ('dBrahms,_Johannes51_Exercises,_WoO_6_**23169', 1),
#  ('dWyman,_Addison_P.Merry_Christmas_1870_**211431', 1),
#  ('dSrebdolskii,_SergeiPiano_Sonata_No.2,_Op.13_**73529', 1),
#  ('dManfroce,_NicolaBiblioteca_d%27oro_**18486', 1),
#  ('dGouin,_PierrePi%C3%A8ces_d%27orgue,_Op.23_**290493', 1),
#  ('dClementi,_Muzio3_Piano_Sonatas,_Op.40_**63303', 1),
#  ('dBach,_Johann_Sebastian6_Partitas,_BWV_825-830_**73879', 1),
#  ('dBach,_Johann_SebastianDas_wohltemperierte_Klavier_II,_BWV_870-893_**22082',
#   1),
#  ('dBach,_Carl_Philipp_EmanuelKeyboard_Sonata_in_A_major,_H.186_**23905', 1),
#  ('dMartucci,_Giuseppe6_Pezzi,_Op.44_**73096', 1),
#  ('dMendelssohn,_Felix3_Etudes,_Op.104b_**109152', 1),
#  ('dMo%C3%B3r,_EmanuelSuite_for_Piano,_Op.77_**62147', 1),
#  ('dCzerny,_Carl160_Kurze_%C3%9Cbungen,_Op.821_**242438', 1),
#  ('dDalla_Libera,_SandroLiber_organi_**32096', 1),
#  ('dMariani,_AngeloBiblioteca_d%27oro_**18486', 1),
#  ('dMendelssohn,_Felix3_Etudes,_Op.104b_**04299', 1),
#  ('dSchubert,_FranzPiano_Sonata_No.18,_D.894_**16607', 1),
#  ('dSchmoll,_AntonL%27union,_Op.47_**330898', 1),
#  ('dYon,_PietroOrgan_Sonata_No.1_**20345', 1),
#  ('dRoberday,_Fran%C3%A7oisLiber_organi_**32096', 1),
#  ('dBeethoven,_Ludwig_vanPiano_Sonata_No.16,_Op.31_No.1_**68736', 1),
#  ('dBoutmy,_JossePi%C3%A8ces_de_clavecin,_Livre_1_**335248', 1),
#  ('dBeliczay,_Gyula3_Moments_musicaux,_Op.46_**481796', 1),
#  ('dClementi,_Muzio3_Piano_Sonatas,_Op.33_**400284', 1),
#  ('dHummel,_Johann_NepomukPiano_Sonata_No.5,_Op.81_**78599', 1),
#  ('dBoutmy,_JossePi%C3%A8ces_de_clavecin,_Livre_2_**335249', 1),
#  ('dScharwenka,_XaverValse-Impromptu,_Op.30_**07443', 1),
#  ('dKalkbrenner,_Friedrich_WilhelmLes_Nationalit%C3%A9s_musicales,_Op.184_**09082',
#   1),
#  ('dGouin,_PierrePremier_livre_de_pi%C3%A8ces_de_clavecin_**299258', 1),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricPreludes,_Op.28_**00485', 1),
#  ('dStojowski,_Sigismond4_Pieces,_Op.26_**04363', 1),
#  ('dMarty,_Adolphe10_Pi%C3%A8ces_en_style_libre_**172807', 1),
#  ('dMagnus,_Desir%C3%A9Chanson_de_l%27esclave,_Op.132_**409745', 1),
#  ('dRawlings,_Charles_ArthurPetit_Galop_de_Concert_**293094', 1),
#  ('dHummel,_Johann_NepomukPiano_Sonata_No.5,_Op.81_**283983', 1),
#  ('dSiewert,_HeinrichGedenke_mein!,_Op.66_**440347', 1),
#  ('dMendelssohn,_Felix3_Etudes,_Op.104b_**109153', 1),
#  ('dReger,_Max4_Preludes_and_Fugues,_Op.85_**05880', 1),
#  ('dSchubert,_FranzPiano_Sonata_No.16,_D.845_**55378', 1),
#  ('dMandyczewski,_Eusebius51_Exercises,_WoO_6_**23169', 1),
#  ('dHummel,_Johann_NepomukPiano_Sonata_No.5,_Op.81_**09525', 1),
#  ('dHensel,_Fanny3_M%C3%A9lodies,_Op.5_**30887', 1),
#  ('dBohm,_Carl3_Danses-Caprices,_Op.334_**278737', 1),
#  ('dCzerny,_Carl2_Sonatinas_faciles_et_brillantes,_Op.49_**366248', 1),
#  ('dAgnew,_RoyContrasts_**422931', 1),
#  ('dArensky,_Anton24_Morceaux_caract%C3%A9ristiques,_Op.36_**518472', 1),
#  ('dDussek,_Jan_LadislavPiano_Sonata_No.21,_Op.45_No.3_**321755', 1),
#  ('dClementi,_Muzio3_Piano_Sonatas,_Op.40_**63302', 1),
#  ('dGouin,_Pierre6_Pi%C3%A8ces_d%27orgue_**240522', 1),
#  ('dCapponi,_FrancescoBiblioteca_d%27oro_**18486', 1),
#  ('dWeyse,_Christoph_Ernst_Friedrich6_Allegros_di_bravura,_Op.1_**34681', 1),
#  ('dCzerny,_CarlVariationen_%C3%BCber_einen_beliebten_Wiener-Walzer,_Op.12_**355925',
#   1),
#  ('dMascheroni,_EdoardoBiblioteca_d%27oro_**18486', 1),
#  ('dReuchsel,_Am%C3%A9d%C3%A9e10_Pi%C3%A8ces_nouvelles,_Op.180_**41862', 1),
#  ('dCzerny,_CarlThe_School_of_Velocity,_Op.299_**01003', 1),
#  ('dOsborne,_George_AlexanderS%C3%A9r%C3%A9nade-nocturne,_Op.89_**350136', 1),
#  ('dGeibel,_AdamNocturne_in_E-flat_major_**236597', 1),
#  ('dGigout,_Eug%C3%A8ne6_Pi%C3%A8ces_d%27orgue_**240522', 1),
#  ('dVilbac,_Renaud_deValse_des_merveilleuses_**415525', 1),
#  ('dClementi,_Muzio3_Piano_Sonatas,_Op.40_**22755', 1),
#  ('dKetterer,_Eug%C3%A8neBluette,_Op.245_**329382', 1),
#  ('dLongo,_AlessandroPiano_Sonata_No.2,_Op.36_**366947', 1),
#  ('dFranek,_GabrielLiebeslied_**465307', 1),
#  ('dBencini,_Pietro_PaoloBiblioteca_d%27oro_**18486', 1),
#  ('dClaussmann,_Alo%C3%BFsImpromptu,_Op.12_**480623', 1),
#  ('dKetterer,_Eug%C3%A8neChant_du_Lido,_Op.177_**328705', 1),
#  ('dBeethoven,_Ludwig_vanPiano_Sonata_No.30,_Op.109_**02021', 1),
#  ('dBeethoven,_Ludwig_vanPiano_Sonata_No.16,_Op.31_No.1_**00016', 1),
#  ('dGouin,_PierreDas_wohltemperierte_Klavier_II,_BWV_870-893_**36337', 1),
#  ('dJensen,_AdolfEt%C3%BCden,_Op.32_**06062', 1),
#  ('dKetten,_HenryMarguerite_au_rouet,_Op.12_**424985', 1),
#  ('dB%C3%BClow,_Hans_von3_Valses_caract%C3%A9ristiques,_Op.18_**198822', 1),
#  ('dGodowsky,_LeopoldValse-Scherzo_**11530', 1),
#  ('dTusquets_y_Maignon,_EstebanScherzo-Vals_**481406', 1),
#  ('dCoye,_Fran%C3%A7isSonata,_Op.28_**79980', 1),
#  ('dWohlfahrt,_HeinrichKinder-Klavierschule_**241611', 1),
#  ('dCapocci,_FilippoOrgan_Sonata_No.4_**308880', 1),
#  ('dClementi,_Muzio2_Capriccios,_Op.47_**400305', 1),
#  ('dOrefice,_Giuseppe_dell%27Biblioteca_d%27oro_**18486', 1),
#  ('dSchubert,_FranzPiano_Sonata_No.18,_D.894_**55383', 1),
#  ('dBesendahl,_CarlIn_der_Waldburg,_Op.30_**423720', 1),
#  ('dMendelssohn,_Felix7_Charakterst%C3%BCcke,_Op.7_**53952', 1),
#  ('dLiszt,_FranzMephisto_Waltz_No.1,_S.514_**89659', 1),
#  ('dSchulhoff,_JuliusGalopp_de_Bravura,_Op.17_**34992', 1),
#  ('dRachmaninoff,_SergeiMoments_musicaux,_Op.16_**03737', 1),
#  ('dRachmaninoff,_SergeiMoments_musicaux,_Op.16_**105590', 1),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricScherzo_No.2,_Op.31_**398167', 1),
#  ('dRudorff,_ErnstScherzo_No.2,_Op.31_**398167', 1),
#  ('dKontski,_Anton_deSouvenir_de_%27Faust%27,_Op.238_**288197', 1),
#  ('dHerz,_HenriVariations_Caract%C3%A9ristiques_sur_un_Th%C3%A8me_Arabe_de_F._Burgm%C3%BCller,_Op.137_**14151',
#   1),
#  ('dLiebling,_EmilMazurka_de_concert,_Op.30_**301950', 1),
#  ('dBotte,_AdolpheCaprice_valse_**403243', 1),
#  ('dH%C3%B6ger,_AntonPi%C3%A8ces_de_clavecin,_Op.1_**110971', 1),
#  ('dGottschalk,_Louis_MoreauDanza,_Op.33_**124822', 1),
#  ('dJohns,_ClaytonValse_**197042', 1),
#  ('dOpel,_W.Le_concert_des_muses_**129104', 1),
#  ('dLincke,_PaulM%C3%BCckenspiele_**489355', 1),
#  ('dMattei,_TitoImpromptu-caprice,_Op.37_**409882', 1),
#  ('dMendelssohn,_FelixLieder_ohne_Worte,_Op.19b_**292188', 1),
#  ('dGrobe,_CharlesAn_Evening_with_Lover,_Op.80_**182637', 1),
#  ('dRudorff,_ErnstWaltzes,_Op.34_**51513', 1),
#  ('dBeethoven,_Ludwig_vanPiano_Sonata_No.16,_Op.31_No.1_**03169', 1),
#  ('dReinecke,_CarlWaltzes,_Op.34_**167282', 1),
#  ('dMandyczewski,_EusebiusFugue,_WoO_8_**23171', 1),
#  ('dSchumann,_RobertDavidsb%C3%BCndlert%C3%A4nze,_Op.6_**72131', 1),
#  ('dColomer,_Blas_Mar%C3%ADa_deMenuet_Renaissance_**364438', 1),
#  ('dOsten,_Fr._vonLe_concert_des_muses_**129104', 1),
#  ('dHiller,_FerdinandLa_Danse_des_F%C3%A9es,_Op.9_**09028', 1),
#  ('dHummel,_Johann_NepomukLa_bella_capricciosa,_Op.55_**113157', 1),
#  ('dBohm,_CarlSalon-Kompositionen,_Op.327_**518223', 1),
#  ('dViereck,_John_ConradJota,_Op.97_**197779', 1),
#  ('dHiller,_FerdinandPiano_Sonata_No.1,_Op.47_**16147', 1),
#  ('dHennessy,_Swan2_Etudes_for_Piano_Left_Hand_**259116', 1),
#  ('dGiese,_TheodorLe_concert_des_muses_**129104', 1),
#  ('dBeethoven,_Ludwig_vanPiano_Sonata_No.6,_Op.10_No.2_**50957', 1),
#  ('dBosquet,_Ars%C3%A8neImpromptu-Valse,_Op.18_**481955', 1),
#  ('dHubert,_AlbertLe_concert_des_muses_**129104', 1),
#  ('dCarvalho,_Ricardo_Ferreira_deSc%C3%A8nes_d%27enfants,_Op.55_**50490', 1),
#  ('dSchunke,_LudwigPiano_Sonata,_Op.3_**187196', 1),
#  ('dSchiffmacher,_JosephSouvenir_de_Monclair,_Op.99_**290646', 1),
#  ('dSchumann,_RobertDavidsb%C3%BCndlert%C3%A4nze,_Op.6_**54411', 1),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricWaltzes,_Op.34_**51513', 1),
#  ('dSchubert,_FranzGalop_and_Ecossaises,_D.735_**38461', 1),
#  ('dPratt,_Silas_GamalielCourt_Minuet_in_E-flat_major_**113256', 1),
#  ('dStudley,_Samuel_L.Fly_to_the_Mountains_**104102', 1),
#  ('dLiszt,_FranzGrande_valse_di_bravura,_S.209_**06410', 1),
#  ('dStudniczka,_V.Le_concert_des_muses_**129104', 1),
#  ('dShaw,_Oliver_J.Les_bords_du_Sauquoit_**114336', 1),
#  ('dBernard,_%C3%89mile2_Impromptus,_Op.32_**512999', 1),
#  ('dMozart,_Wolfgang_AmadeusRondo_in_D_major,_K.485_**56693', 1),
#  ('dGouin,_PierreFugue,_WoO_8_**23171', 1),
#  ('dBazin,_JosephValse_souveraine,_Op.30_**516036', 1),
#  ('dBerlioz,_HectorS%C3%A9r%C3%A9nade_agreste_%C3%A0_la_madone_sur_la_th%C3%A8me_des_pifferari_romains,_H_98_**205184',
#   1),
#  ('dKontski,_Anton_de3_M%C3%A9ditations,_Op.42_**447511', 1),
#  ('dBach,_Nicolas_GottlibeAmusement_de_Salon,_Op.12_**383665', 1),
#  ('dWollenhaupt,_Hermann_AdolfGrande_valse_brillante,_Op.54_**26858', 1),
#  ('dRachmaninoff,_Sergei13_Preludes,_Op.32_**00344', 1),
#  ('dSchumann,_RobertDavidsb%C3%BCndlert%C3%A4nze,_Op.6_**289905', 1),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricGrande_valse_brillante,_Op.18_**86697', 1),
#  ('dHeller,_StephenVariations_on_a_Theme_of_Schumann,_Op.142_**08524', 1),
#  ('dRyder,_Thomas_PhilandoLast_Rose_of_Summer,_Op.68_**113955', 1),
#  ('dRubinstein,_Anton6_Etudes,_Op.23_**04131', 1),
#  ('dBrahms,_JohannesFugue,_WoO_8_**23171', 1),
#  ('dKeil,_Alfredo12_M%C3%A9lodies,_Op.9_**110406', 1),
#  ('dPlessen,_Friedrich_Leopold_vonErinnerung_an_die_erste_Liebe,_Op.50_**62218',
#   1),
#  ('dMattei,_TitoLe_tourbillon,_Op.22_**409860', 1),
#  ('dWallace,_William_VincentFantasie_elegante_sur_des_themes_de_%27Don_Pasquale%27_**251030',
#   1),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricMazurkas,_Op.41_**86547', 1),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricGrande_valse_brillante,_Op.18_**79744', 1),
#  ('dDalla_Libera,_SandroLiber_organi_**32091', 1),
#  ('dSchubert,_Franz12_German_Dances,_D.790_**03148', 1),
#  ('dSmith,_SydneyFantaisie_Brillante_on_%27Faust%27,_Op.117_**36103', 1),
#  ('dPessard,_%C3%89mileGrande_valse_No.1,_Op.13_**412724', 1),
#  ('dMoszkowski,_Moritz5_Klavierst%C3%BCcke,_Op.18_**33662', 1),
#  ('dKogel,_Gustav_Friedrich3_Tonst%C3%BCcke,_Op.4_**353046', 1),
#  ('dSchubert,_FranzGalop_and_Ecossaises,_D.735_**38460', 1),
#  ('dRubinstein,_Anton2_M%C3%A9lodies,_Op.3_**16244', 1),
#  ('dWalther,_AugustScenes_on_the_Hudson,_Op.3_**294227', 1),
#  ('dBassford,_T._FranklinThe_Eglantine_Polka_**397257', 1),
#  ('dDelioux,_CharlesOrientale,_Op.42_**394109', 1),
#  ('dSchumann,_RobertFantasiest%C3%BCcke,_Op.12_**289804', 1),
#  ('dStanchinsky,_AlekseyEtude_in_G_minor_**359796', 1),
#  ('dMusard,_Philippe2_Quadrilles_de_Contredanses_sur_%27Le_Domino_Noir%27_**56044',
#   1),
#  ('dCzerny,_CarlSouvenir_de_Bellini,_Op.386_**361669', 1),
#  ('dLiszt,_FranzR%C3%A9miniscences_de_Don_Juan,_S.418_**95879', 1),
#  ('dKohler,_EmileLe_Volga,_Op.6_**438165', 1),
#  ('dGodowsky,_LeopoldFr%C3%BChlingsnacht_**168892', 1),
#  ('dMascheroni,_EdoardoBiblioteca_d%27oro_**18493', 1),
#  ('dGottschalk,_Louis_MoreauSuis_Moi!,_Op.45_**07730', 1),
#  ('dWollenhaupt,_Hermann_AdolfGrande_marche_militaire,_Op.31_**105836', 1),
#  ('dFranck,_Eduard6_Piano_Sonatas,_Op.40_**382601', 1),
#  ('dHerzberg,_AntonLe_concert_des_muses_**129104', 1),
#  ('d%C5%A0%C5%A5astn%C3%BD,_Ludv%C3%ADkLe_concert_des_muses_**129104', 1),
#  ('dReinecke,_CarlWaltzes,_Op.34_**51515', 1),
#  ('dKlein,_JulesTruite_aux_perles!_**408191', 1),
#  ('dUlrich,_Hugo38_Waltzes,_L%C3%A4ndler_and_Ecossaises,_D.145_**37832', 1),
#  ('dReinhold,_HugoTanz-Szenen,_Op.65_**406005', 1),
#  ('dSatie,_ErikMenus_propos_enfantins_**198846', 1),
#  ('dWallace,_William_VincentLa_Cracovienne_**113559', 1),
#  ('dBrambach,_Carl_Joseph4_Charakteristische_St%C3%BCcke,_Op.71_**90518', 1),
#  ('dSpindler,_FritzAlbum_beliebter_russischer_Romanzen,_Op.288_**286479', 1),
#  ('dKroeger,_Ernest_RichardValse_brillante_**317835', 1),
#  ('dSteibelt,_DanielCommemorative_Overture_**485021', 1),
#  ('dWeber,_Carl_Maria_von6_Variations_sur_un_th%C3%A8me_original,_Op.2_**385679',
#   1),
#  ('dChavagnat,_EdouardPetites_Choses,_Op.217_**496753', 1),
#  ('dNeustedt,_CharlesFantaisie-transcription_sur_%27L%27oca_del_Cairo%27,_Op.75_**377569',
#   1),
#  ('dBlake,_Charles_DupeeGolden_Clouds,_Op.166_**103536', 1),
#  ('dGoldner,_WilhelmValse_des_papillons,_Op.33_**262256', 1),
#  ('dCloy,_Charles_V.Bright_as_Daisies_**397016', 1),
#  ('dThompson,_Alexander_StewartPiano_Sonata,_Op.21_No.1_**378019', 1),
#  ('dKafka,_Johann_NepomukTiroler_Heimatkl%C3%A4nge,_Op.138_**406569', 1),
#  ('dMayer,_CharlesFleurs_d%27automne,_Op.210_**357710', 1),
#  ('dRaison,_Andr%C3%A9Liber_organi_**32091', 1),
#  ('dDietrich,_MauriceLa_Suppliante_**446227', 1),
#  ('dWolfrum,_PhilippOrgan_Sonata_No.2,_Op.10_**323521', 1),
#  ('dWillmers,_RudolfPiano_Sonata,_Op.33_**389364', 1),
#  ('dGobbi,_HenriPiano_Sonata_No.1,_Op.13_**455612', 1),
#  ('dKirchner,_TheodorAquarellen,_Op.21_**08111', 1),
#  ('dCzerny,_CarlDie_Schule_des_Vortrags_und_der_Verzierungen,_Op.575_**363412',
#   1),
#  ('dBristow,_George_FrederickGrand_Waltz_de_Bravura,_Op.6_**76871', 1),
#  ('dDraeseke,_Felix2_Valses_de_concert,_Op.4_**446254', 1),
#  ('dGregoir,_JacquesMorceau_de_salon,_Op.33_**394071', 1),
#  ('dGrube,_Charles_H.Shells_of_the_Ocean_**104491', 1),
#  ('dHewitt,_John_HillThe_Fairmount_Quadrilles_**457175', 1),
#  ('dScriabin,_AleksandrAllegro_de_concert,_Op.18_**08378', 1),
#  ('dKuhlau,_Friedrich3_Leichte_Rondos_%C3%BCber_beliebte_Opern_Melodien,_Op.31_**437470',
#   1),
#  ('dBerger,_WilhelmPiano_Sonata,_Op.76_**84632', 1),
#  ('dWestendorf,_Thomas_PayneThe_Little_Tin_Trumpet_**413456', 1),
#  ('dChristensen,_Alfred_FerdinandLove_Poems_**344686', 1),
#  ('dS%C3%A9rieux,_Ch.Le_concert_des_muses_**129104', 1),
#  ('dScott,_JamesThe_Ragtime_Betty_**391649', 1),
#  ('dMoszkowski,_Moritz3_Morceaux,_Op.34_**262613', 1),
#  ('dBo%C3%ABllmann,_L%C3%A9onHeures_mystiques,_Opp.29-30_**270259', 1),
#  ('dKeil,_Alfredo12_M%C3%A9lodies,_Op.9_**110416', 1),
#  ('dHeyer,_OttoLe_concert_des_muses_**129104', 1),
#  ('dGrobe,_CharlesAirs_from_Mozart%27s_12th_Mass,_Op.533_**175443', 1),
#  ('dGottschalk,_Louis_MoreauGrande_fantaisie_triomphale_sur_l%27hymne_national_br%C3%A9silien,_Op.69_**265395',
#   1),
#  ('dCzerny,_CarlPanorama_beliebter_Melodien_aller_Nationen,_Op.729_**359639',
#   1),
#  ('dWallace,_William_VincentForget_Me_Not_**251937', 1),
#  ('dMaylath,_HenryFanfare_**380950', 1),
#  ('dBaroni-Cavalcab%C3%B3,_JulieFantaisie,_Op.19_**388863', 1),
#  ('dDvo%C5%99%C3%A1k,_Anton%C3%ADnWaltzes,_Op.54_**95072', 1),
#  ('dLetocart,_HenriLa_Lyre_Catholique_**442350', 1),
#  ('dWallace,_William_VincentLa_Cracovienne_**113558', 1),
#  ('dHahn,_ReynaldoLe_rossignol_%C3%A9perdu_**45455', 1),
#  ('dJan%C3%A1%C4%8Dek,_Leo%C5%A1On_the_Overgrown_Path_**09955', 1),
#  ('dRavina,_Jean_HenriL%27enchanteresse,_Op.61_**19643', 1),
#  ('dQuidant,_AlfredGrande_Etude-Galop,_Op.21_**32168', 1),
#  ('dFuchs,_RobertWaltzes,_Op.110_**64116', 1),
#  ('dRudorff,_ErnstWaltzes,_Op.34_**51515', 1),
#  ('dSpindler,_FritzRienzi,_Op.235_**368899', 1),
#  ('dMayerh%C3%B6fer,_A.Le_concert_des_muses_**129104', 1),
#  ('dMarmontel,_Antoine_Fran%C3%A7oisAllegro_fuocoso,_Op.118_**350133', 1),
#  ('dSieg,_ConstantSylvia,_Op.46_**289494', 1),
#  ('dCzerny,_CarlThe_Art_of_Finger_Dexterity,_Op.740_**12221', 1),
#  ('dGr%C3%A4dener,_Carl_Georg_PeterFantastische_Studien_und_Tr%C3%A4umereien,_Op.52_**259686',
#   1),
#  ('dSatias,_Eug%C3%A8neGard%C3%A9nia_**363046', 1),
#  ('dLeber,_AugusteAlsace,_Op.25_**456916', 1),
#  ('dWieniawski,_J%C3%B3zef4_Klavierst%C3%BCcke,_Op.51_**444955', 1),
#  ('dMandyczewski,_EusebiusValses_sentimentales,_D.779_**33197', 1),
#  ('dLiszt,_FranzValse-Impromptu,_S.213_**06413', 1),
#  ('dHeller,_Stephen24_Preludes,_Op.81_**263751', 1),
#  ('dRudorff,_ErnstWaltzes,_Op.34_**167282', 1),
#  ('dHummel,_Johann_NepomukPiano_Sonata_No.2,_Op.13_**09520', 1),
#  ('dH%C3%B6ger,_AntonTiento_1_del_primer_tono_**345360', 1),
#  ('dLange,_GustavFantasien_%C3%BCber_beliebte_Lieder,_Op.172_**205635', 1),
#  ('dStrozzi,_BarbaraBiblioteca_d%27oro_**18493', 1),
#  ('dPacher,_Josef_AdalbertDie_Deb%C3%BCtanten,_Op.32_**134554', 1),
#  ('dMasarnau,_Santiago_deFantasia,_Op.21_**456977', 1),
#  ('dCzerny,_CarlSonata_in_the_Style_of_Domenico_Scarlatti,_Op.788_**356848',
#   1),
#  ('dHeller,_StephenFeuilles_volantes,_Op.123_**103282', 1),
#  ('dWilson,_Grenville_DeanTwinkling_Stars,_Op.63_**183365', 1),
#  ('dMattiozzi,_RodolfoLa_volutta_**479732', 1),
#  ('dKnuth,_J%C3%BCrgen12_Variations_on_%22Ah,_vous_dirai-je_maman%22,_K.265**40557',
#   1),
#  ('dMullen,_Alfred_FredericIn_Normandy_**301290', 1),
#  ('dZar%C4%99bski,_JuliuszBarcarolle,_Op.31_**16610', 1),
#  ('dLanner,_JosephCotillons_on_Themes_from_%27I_Capuleti_e_i_Montecchi%27,_Op.72_**115485',
#   1),
#  ('dUnderner,_JohnMagdalena_Polka_**115874', 1),
#  ('dBeethoven,_Ludwig_vanPiano_Sonata_No.8,_Op.13_**195385', 1),
#  ('dSmith,_SydneyGrande_Fantaisie_de_Concert_on_%27Der_Freischuetz%27,_Op.16_**112055',
#   1),
#  ('dSchubert,_Franz12_German_Dances,_D.790_**53753', 1),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricWaltzes,_Op.34_**167282', 1),
#  ('dBrahms,_JohannesVariations_on_a_Theme_by_Robert_Schumann,_Op.9_**08431',
#   1),
#  ('dK%C3%B6hler,_L._UnicoLe_concert_des_muses_**129104', 1),
#  ('dStrack,_LouisThe_Gold_Mines_of_California_**252029', 1),
#  ('dH%C3%A4gg,_GustafLa_Coquette,_Op.10_**433379', 1),
#  ('dVoigt,_M.6_Miniatures,_Op.8_**396413', 1),
#  ('dBarbirolli,_AlfredoAddio_**515384', 1),
#  ('dScriabin,_AleksandrAllegro_de_concert,_Op.18_**10801', 1),
#  ('dField,_JohnPiano_Sonata_in_B_major,_H_17_**09792', 1),
#  ('dPlessen,_Friedrich_Leopold_vonNordland%27s_Lust,_Op.41_**61382', 1),
#  ('dHenselt,_Adolf_vonPr%C3%A9ambules_dans_tous_les_tons_**385608', 1),
#  ('dWilson,_Grenville_DeanFare_Thee_Well,_Op.68_**270458', 1),
#  ('dSpindler,_FritzRienzi,_Op.235_**420834', 1),
#  ('dMattei,_TitoGrande_valse_de_concert_**512478', 1),
#  ('dBeethoven,_Ludwig_vanPiano_Sonata_No.5,_Op.10_No.1_**50957', 1),
#  ('dMoelling,_TheodoreDance_of_the_May_Queen,_Op.28_**186572', 1),
#  ('dSmith,_SydneyGrande_Fantaisie_on_%27Guillaume_Tell%27,_Op.61_**54638', 1),
#  ('dWidor,_Fran%C3%A7ois-CharlesChant_du_Meunier,_Op.12_**441357', 1),
#  ('dReinecke,_CarlWaltzes,_Op.34_**51514', 1),
#  ('dRemiehleki,_D.Doux_penser_**505837', 1),
#  ('dBehr,_FranzFr%C3%BChling_und_Liebe_**98581', 1),
#  ('dLiszt,_FranzTarantelle_di_bravura_d%27apr%C3%A8s_la_tarantelle_de_La_muette_de_Portici,_S.386_**95914',
#   1),
#  ('dSteibelt,_DanielPiano_Sonata_in_E-flat_major,_Op.45_**486501', 1),
#  ('dScriabin,_AleksandrAllegro_de_concert,_Op.18_**09757', 1),
#  ('dFradel,_CharlesPiano_Sonatinas,_Op.505_**82118', 1),
#  ('dGranados,_EnriqueEl_jard%C3%AD_d%E2%80%99Elisenda_**338495', 1),
#  ('dKetterer,_Eug%C3%A8neMarche_hongroise,_Op.63_**64169', 1),
#  ('dBrowne,_AugustaFantasia_and_Variations_on_the_Vesper_Hymn,_Op.35_**445582',
#   1),
#  ('dCabez%C3%B3n,_Antonio_deTiento_1_del_primer_tono_**345360', 1),
#  ('dUlrich,_HugoValses_sentimentales,_D.779_**33197', 1),
#  ('dGr%C3%BCnfeld,_Alfred4_Morceaux,_Op.50_**84034', 1),
#  ('dRoubier,_HenriParfait_bonheur,_Op.53_**257198', 1),
#  ('dDvo%C5%99%C3%A1k,_Anton%C3%ADnWaltzes,_Op.54_**95073', 1),
#  ('dCzerny,_Carl32_Nouveaux_exercices_journaliers,_Op.848_**267064', 1),
#  ('dSchulhoff,_JuliusCaprice_sur_des_airs_boh%C3%A9miens,_Op.10_**28644', 1),
#  ('dKirchner,_Theodor4_Polonaises,_Op.43_**08268', 1),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricPolonaises,_Op.71_**80604', 1),
#  ('dBattmann,_Jacques-LouisIndiana,_Op.239_**522505', 1),
#  ('dCzerny,_CarlPiano_Sonata_No.2,_Op.13_**06539', 1),
#  ('dWeber,_Carl_Maria_von6_Variations_sur_l%27air_de_Naga_de_%27Samori%27,_Op.6_**385682',
#   1),
#  ('dSchubert,_Franz12_Grazer_Waltzer,_D.924_**03147', 1),
#  ('dSchmoll,_AntonBrennus,_Op.45_**330893', 1),
#  ('dMandyczewski,_EusebiusVariations_on_a_Theme_by_Robert_Schumann,_Op.9_**08431',
#   1),
#  ('dJa%C3%ABll,_AlfredIllustrations_sur_un_Motiv_de_Verdi%27s_%27Rigoletto%27,_Op.18_**21225',
#   1),
#  ('dCzerny,_CarlThe_School_of_Embellishments,_Op.355_**310385', 1),
#  ('dAshton,_Algernon5_Klavierst%C3%BCcke,_Op.127_**363599', 1),
#  ('dSchubert,_Franz38_Waltzes,_L%C3%A4ndler_and_Ecossaises,_D.145_**37832', 1),
#  ('dStojowski,_SigismondAus_Sturm_und_Stille,_Op.29_**04365', 1),
#  ('dButtlar-Stubenberg,_Anna_vonDie_Kapfenberger,_Op.67_**100338', 1),
#  ('dMoscheles,_IgnazGrande_sonate,_Op.41_**257209', 1),
#  ('dReinecke,_CarlWaltzes,_Op.34_**51513', 1),
#  ('dAlyabyev,_AleksandrPolonaise_in_E-flat_major_**42673', 1),
#  ('dLiszt,_FranzR%C3%A9miniscences_de_Don_Juan,_S.418_**95880', 1),
#  ('dLeoncavallo,_Ruggiero2_Morceaux_**366260', 1),
#  ('dHill,_Edward_Burlingame4_Sketches_after_Stephen_Crane,_Op.7_**12876', 1),
#  ('dGutmann,_Adolf2_Nocturnes,_Op.16_**381002', 1),
#  ('dM%C3%A9reaux,_Jean-Am%C3%A9d%C3%A9e_Lefroid_deBallade,_Op.60_**14897', 1),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricWaltzes,_Op.34_**51515', 1),
#  ('dSchumann,_ClaraCaprices_en_forme_de_valses,_Op.2_**374017', 1),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricWaltzes,_Op.34_**51514', 1),
#  ('dSchumann,_RobertPiano_Sonata_No.3,_Op.14_**00410', 1),
#  ('dBeethoven,_Ludwig_vanAndante_favori,_WoO_57_**51427', 1),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricBallade_No.4,_Op.52_**41181', 1),
#  ('dChaminade,_C%C3%A9cile2_Mazurkas,_Op.1b_**262192', 1),
#  ('dLange,_GustavArabesken,_Op.79_**204928', 1),
#  ('dMozart,_Wolfgang_Amadeus12_Variations_on_%22Ah,_vous_dirai-je_maman%22,_K.265**40557',
#   1),
#  ('dSaint-Sa%C3%ABns,_CamilleMenuet_et_Valse,_Op.56_**07529', 1),
#  ('dRudorff,_ErnstWaltzes,_Op.34_**51514', 1),
#  ('dFalke,_GustavDeutscher_Walzer,_Op.2_**398491', 1),
#  ('dChristensen,_Alfred_FerdinandLove_Poems_**344426', 1),
#  ('dSchubert,_FranzValses_sentimentales,_D.779_**33197', 1),
#  ('dWeyse,_Christoph_Ernst_FriedrichAllegros_di_bravura,_Op.16_**33613', 1),
#  ('dKaulich,_JosefWiener_Herzen,_Op.66_**261136', 1),
#  ('dRoberday,_Fran%C3%A7oisLiber_organi_**32091', 1),
#  ('dGouin,_PierreHeures_mystiques,_Opp.29-30_**270259', 1),
#  ('dCzerny,_CarlImpromptu_sentimental_sur_%27O_nume_benefico%27,_Op.523_**356518',
#   1),
#  ('dBeethoven,_Ludwig_vanPiano_Sonata_No.7,_Op.10_No.3_**50957', 1),
#  ('dWeiss,_JosefSuite_in_Walzerform_for_Piano,_Op.40_**421851', 1),
#  ('dV%C3%A9ley,_CarlLes_nymphes_de_la_mer_**363934', 1),
#  ('dWolff,_%C3%89douard2_Chansons_polonaises,_Opp.219-220_**488671', 1),
#  ('dTedesco,_IgnazAlbum_de_Salon,_Op.75_**446445', 1),
#  ('dRies,_FerdinandA_Moldavian_Air_with_Variations,_Op.105_No.4_**452883', 1),
#  ('dNogu%C3%A9s_i_Torras,_AntoniCapricho_Espa%C3%B1ol_**76687', 1),
#  ('dLeybach,_Ignace_Xavier_JosephGrande_valse_brillante_No.2,_Op.20_**202571',
#   1),
#  ('dKalkbrenner,_Friedrich_WilhelmIntroduction_et_polonaise_brillante,_Op.141_**288784',
#   1),
#  ('dB%C3%BClow,_Hans_vonIl_Carnevale_di_Milano,_Op.21_**55484', 1),
#  ('dKontski,_Anton_deSouvenir_de_Varsovie,_Op.159_**447550', 1),
#  ('dDussek,_Jan_LadislavPiano_Sonata_No.18,_Op.44_**244352', 1),
#  ('dMullen,_Alfred_FredericSpring_Tales_**301295', 1),
#  ('dD%C3%B6hler,_Theodor4_Fantasies_on_Themes_from_Operas_by_Donizetti_and_Bellini,_Op.14_**109520',
#   1),
#  ('dVanderbeck,_F._E.Edelweiss_Glide_Waltz_**317911', 1),
#  ('dAulin,_Valborg7_Piano_Pieces,_Op.8_**432359', 1),
#  ('dSomervell,_ArthurThe_Romance_of_the_Ball_**56973', 1),
#  ('dDurand,_AugusteValse_No.2,_Op.86_**271029', 1),
#  ('dButler,_LeonardAt_Nightfall_**315806', 1),
#  ('dRuiz_Espadero,_Nicol%C3%A1sChant_du_guagiro,_Op.61_**410895', 1),
#  ('dAshton,_Algernon2_Pieces,_Op.145_**363603', 1),
#  ('dJungmann,_AlbertMarie,_Op.160_**474417', 1),
#  ('dJa%C3%ABll,_AlfredPrima_Donna_Waltz,_Op.30_**03745', 1),
#  ('dHerz,_JacquesGrande_valse_brilliante,_Op.37_**12885', 1),
#  ('dNiewiadomski,_Stanis%C5%82aw6_Morceaux_m%C3%A9lodiques,_Op.34_**446169',
#   1),
#  ('dGlazunov,_Aleksandr3_Miniatures,_Op.42_**02712', 1),
#  ('dSchindler,_FritzBist_du_mir_gut%3F,_Op.100_**400182', 1),
#  ('dHummel,_Johann_NepomukLa_galante,_Op.120_**09527', 1),
#  ('dBarmotin,_Semyon10_Pieces,_Op.6_**08539', 1),
#  ('dWollenhaupt,_Hermann_Adolf2_Morceaux_**105505', 1),
#  ('dWollenhaupt,_Hermann_AdolfFunkelnde_Diamanten,_Op.53_**427677', 1),
#  ('dCourlander,_BernhardUn_jour_d%27%C3%A9t%C3%A9,_Op.23_**113548', 1),
#  ('dTedesco,_IgnazGrande_Valse_brillante_No.2,_Op.40_**446443', 1),
#  ('dGodefroid,_F%C3%A9lixAir_montagnard,_Op.138_**416251', 1),
#  ('dAlkan,_Charles-Valentin25_Preludes,_Op.31_**02978', 1),
#  ('dReinecke,_CarlWaltz_in_A-flat_major,_Op.42_**82599', 1),
#  ('dJohnson,_BernardFaerie_Suite_**316282', 1),
#  ('dMack,_EdwardSilver_Wedding_March_**105520', 1),
#  ('dBehr,_FranzNouvelles_Compositions_**430994', 1),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricWaltz_in_A-flat_major,_Op.42_**82599', 1),
#  ('dRudorff,_ErnstWaltz_in_A-flat_major,_Op.42_**82599', 1),
#  ('dKappes,_J._HenryUne_fleur_d%27amour,_Op.74_**247482', 1),
#  ('dMendelssohn,_FelixCapriccio,_Op.118_**109261', 1),
#  ('dCadman,_Charles_WakefieldLegend_and_Caprice,_Op.30_**173156', 1),
#  ('dAstort_Ribas,_PedroCharmant_**508381', 1),
#  ('dLeschetizky,_Theodor2_Mazurkas,_Op.24_**10277', 1),
#  ('dChaminade,_C%C3%A9cileLa_Livry,_Op.51_**36569', 1),
#  ('dLiebling,_EmilFlorence,_Op.12_**76838', 1),
#  ('dMattei,_TitoLe_nid_et_la_rose_**409911', 1),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricWaltz_in_A-flat_major,_Op.42_**51527', 1),
#  ('dButler,_LeonardOutdoor_Life_**346371', 1),
#  ('dRheinberger,_Josef_GabrielPr%C3%A4ludien_in_Et%C3%BCdenform,_Op.14_**371845',
#   1),
#  ('dLiszt,_FranzAnn%C3%A9es_de_p%C3%A8lerinage_II,_S.161_**55481', 1),
#  ('dRavina,_Jean_Henri%C3%89tudes_de_style_et_de_perfectionnement,_Op.14_**174150',
#   1),
#  ('dKnuth,_J%C3%BCrgenLa_pri%C3%A8re_d%27une_vierge,_Op.4_**171815', 1),
#  ('dCzerny,_CarlThe_Art_of_Finger_Dexterity,_Op.740_**04064', 1),
#  ('dFarrenc,_LouiseLes_Italiennes,_Op.14_**511617', 1),
#  ('dBillema,_RaffaeleDas_Gezwitscher_der_V%C3%B6gel,_Op.48_**364550', 1),
#  ('dRudorff,_ErnstWaltz_in_A-flat_major,_Op.42_**51528', 1),
#  ('dCzerny,_Carl2_Rondeaux_brillants_sur_%27La_Part_du_Diable%27,_Op.742_**366504',
#   1),
#  ('dR%C3%B6ntgen,_JuliusNeckens_Polka,_Op.11_**07780', 1),
#  ('dH%C3%BCnten,_Fran%C3%A7oisLes_%C3%A9meraudes,_Op.128_**125462', 1),
#  ('dAlkan,_Charles-Valentin25_Preludes,_Op.31_**519853', 1),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricWaltz_in_A-flat_major,_Op.42_**114891', 1),
#  ('dMerkel,_Gustav_AdolfPolonaise_brillante,_Op.28_**391684', 1),
#  ('dRebikov,_VladimirM%C3%A9lomimiques,_Op.17_**32902', 1),
#  ('dDubois,_Th%C3%A9odore20_Pi%C3%A8ces_nouvelles_**30495', 1),
#  ('dAlkan,_Charles-Valentin25_Preludes,_Op.31_**519854', 1),
#  ('dDubois,_Th%C3%A9odore20_Pi%C3%A8ces_nouvelles_**30480', 1),
#  ('dSauer,_Emil_vonConcert_Etudes_Nos.11-20_**389798', 1),
#  ('dKalafati,_Vasily2_Piano_Sonatas,_Op.4_**09965', 1),
#  ('dKirchner,_TheodorAlbumbl%C3%A4tter,_Op.7_**55813', 1),
#  ('dChansarel,_Ren%C3%A9Fantaisies_sur_un_Th%C3%A8me_original_**99520', 1),
#  ('dRudorff,_ErnstWaltz_in_A-flat_major,_Op.42_**114891', 1),
#  ('dMacDowell,_Edward12_Virtuoso_Etudes,_Op.46_**218876', 1),
#  ('dLange,_GustavFloridiana,_Op.59_**204911', 1),
#  ('dGottschalk,_Louis_MoreauLa_Brise_**378072', 1),
#  ('dAshton,_Algernon2_Pieces,_Op.145_**88268', 1),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricPreludes,_Op.28_**86359', 1),
#  ('dChopin,_Fr%C3%A9d%C3%A9ricWaltz_in_A-flat_major,_Op.42_**51528', 1),
#  ('dMarcailhou,_GatienIndiana_**403025', 1),
#  ('dKetterer,_Eug%C3%A8neLe_triomphe,_Op.221_**328456', 1),
#  ('dSchytte,_LudvigLeichte_charakteristische_Et%C3%BCden,_Op.95_**411371', 1),
#  ('dSauer,_Emil_vonConcert_Etudes_Nos.11-20_**55959', 1),
#  ('dMendelssohn,_FelixCapriccio,_Op.118_**109262', 1),
#  ('dSchumann,_RobertHumoreske,_Op.20_**00716', 1),
#  ('dZar%C4%99bski,_JuliuszBallade,_Op.18_**504906', 1),
#  ('dBlumenthal,_JacquesLes_deux_anges,_Op.8_**429176', 1),
#  ('dVierne,_LouisSymphonie_No.2,_Op.20_**04006', 1),
#  ('dSch%C3%BCtt,_Eduard3_Morceaux,_Op.37_**465975', 1),
#  ('dReinecke,_CarlWaltz_in_A-flat_major,_Op.42_**51527', 1),
#  ('dBohm,_CarlMon_Bijou_**29755', 1),
#  ...]

# %%
def processQuery_wrapper(queryfile, rindex, counts,  outdir, mode):
    # wrapper for running multiple jobs in parallel
    basename = os.path.splitext(os.path.basename(queryfile))[0] # e.g. p1_q1
    hyp_outfile = "{}/{}.hyp".format(outdir, basename)
    piece = basename.split('_')[0]
    return processSingleQuery(queryfile, rindex, counts,  hyp_outfile, mode)

# %%
# process all queries
#pickle_file = 'experiments/indices/**index.pkl'
pickle_file = 'experiments/indices/N_GRAM_1_ALL.pkl'
pickle_map = 'experiments/indices/N_GRAM_1_ALL_MAP.pkl'
query_list = 'cfg_files/query.test.list' # list of query images
outdir = 'experiments/lol/hyp' # where to save hypothesis output files
mode = "Dynamic_Static"

# prep output directory
if not os.path.isdir(outdir):
    os.makedirs(outdir)

# load reverse index. Recommend keeping load=False and loading it earlier.
load = False
if load:
    print("LOADING RINDEX")
    rindex1 = []
    with open(pickle_file, 'rb') as f:
        rindex1 = pickle.load(f)
    with open(pickle_map, 'rb') as f:
        fpMap = pickle.load(f)
    condense = False
    rindex_filter = rindex1
    if condense :
        rindex_filter = copy.deepcopy(rindex1)
        for key in rindex1:
            s = 0
            for piece in rindex1[key].keys():
                s +=len(rindex1[key][piece])
            if s > 200000:
                rindex_filter.pop(key, None)
if mode == "N_GRAM":
    counts = []

print("STARTING PROCESSING")
# number of cores to use
multiprocess = False
if multiprocess:
    n_cores = 25 #multiprocessing.cpu_count()
    pool = multiprocessing.Pool(processes=n_cores)

inputs = []
with open(query_list, 'r') as f:
    for line in f:
        inputs.append((line.rstrip(), outdir))

if multiprocess:
    # process queries in parallel
    outputs = list(pool.starmap(processQuery_wrapper, inputs))
else:
    for i in inputs:
        processQuery_wrapper(i[0],rindex_filter, counts,i[1], mode = mode)
# Out:
# STARTING PROCESSING
# Processing data/queries/p2_q1.jpg
# 1.1773545742034912
# Processing data/queries/p2_q2.jpg
# 1.108424186706543
# Processing data/queries/p2_q3.jpg
# 1.115931749343872
# Processing data/queries/p2_q4.jpg
# 1.0421009063720703
# Processing data/queries/p2_q5.jpg
# 1.1063766479492188
# Processing data/queries/p2_q6.jpg
# 1.0875537395477295
# Processing data/queries/p2_q7.jpg
# 1.0651390552520752
# Processing data/queries/p2_q8.jpg
# 1.197953701019287
# Processing data/queries/p2_q9.jpg
# 1.1133928298950195
# Processing data/queries/p2_q10.jpg
# 1.07210111618042
# Processing data/queries/p3_q1.jpg
# 1.1783912181854248
# Processing data/queries/p3_q2.jpg
# 1.5363390445709229
# Processing data/queries/p3_q3.jpg
# 1.3707642555236816
# Processing data/queries/p3_q4.jpg
# 1.3239538669586182
# Processing data/queries/p3_q5.jpg
# 1.1494011878967285
# Processing data/queries/p3_q6.jpg
# 1.3979241847991943
# Processing data/queries/p3_q7.jpg
# 1.417079210281372
# Processing data/queries/p3_q8.jpg
# 1.2414305210113525
# Processing data/queries/p3_q9.jpg
# 1.2903521060943604
# Processing data/queries/p3_q10.jpg
# 1.2420666217803955
# Processing data/queries/p4_q1.jpg
# 1.140467643737793
# Processing data/queries/p4_q2.jpg
# 1.0415549278259277
# Processing data/queries/p4_q3.jpg
# 1.1011226177215576
# Processing data/queries/p4_q4.jpg
# 1.027308464050293
# Processing data/queries/p4_q5.jpg
# 1.180049180984497
# Processing data/queries/p4_q6.jpg
# 1.0424609184265137
# Processing data/queries/p4_q7.jpg
# 1.0782911777496338
# Processing data/queries/p4_q8.jpg
# 1.1044268608093262
# Processing data/queries/p4_q9.jpg
# 1.003805160522461
# Processing data/queries/p4_q10.jpg
# 1.09535551071167
# Processing data/queries/p6_q1.jpg
# 1.3306996822357178
# Processing data/queries/p6_q2.jpg
# 1.216352939605713
# Processing data/queries/p6_q3.jpg
# 1.1125717163085938
# Processing data/queries/p6_q4.jpg
# 1.4302916526794434
# Processing data/queries/p6_q5.jpg
# 1.4858014583587646
# Processing data/queries/p6_q6.jpg
# 1.18934965133667
# Processing data/queries/p6_q7.jpg
# 1.1896934509277344
# Processing data/queries/p6_q8.jpg
# 1.2669250965118408
# Processing data/queries/p6_q9.jpg
# 1.578514575958252
# Processing data/queries/p6_q10.jpg
# 1.5040647983551025
# Processing data/queries/p7_q1.jpg
# 1.4140779972076416
# Processing data/queries/p7_q2.jpg
# 1.2529287338256836
# Processing data/queries/p7_q3.jpg
# 1.3488843441009521
# Processing data/queries/p7_q4.jpg
# 1.2976388931274414
# Processing data/queries/p7_q5.jpg
# 1.4768645763397217
# Processing data/queries/p7_q6.jpg
# 1.4943022727966309
# Processing data/queries/p7_q7.jpg
# 1.717261552810669
# Processing data/queries/p7_q8.jpg
# 1.3482882976531982
# Processing data/queries/p7_q9.jpg
# 1.1188740730285645
# Processing data/queries/p7_q10.jpg
# 1.1400134563446045
# Processing data/queries/p8_q1.jpg
# 1.1989338397979736
# Processing data/queries/p8_q2.jpg
# 1.1554362773895264
# Processing data/queries/p8_q3.jpg
# 1.2162320613861084
# Processing data/queries/p8_q4.jpg
# 1.206099271774292
# Processing data/queries/p8_q5.jpg
# 1.1813185214996338
# Processing data/queries/p8_q6.jpg
# 1.288057565689087
# Processing data/queries/p8_q7.jpg
# 1.2878494262695312
# Processing data/queries/p8_q8.jpg
# 1.2410252094268799
# Processing data/queries/p8_q9.jpg
# 1.148571491241455
# Processing data/queries/p8_q10.jpg
# 1.301093578338623
# Processing data/queries/p9_q1.jpg
# 1.2629249095916748
# Processing data/queries/p9_q2.jpg
# 1.3917460441589355
# Processing data/queries/p9_q3.jpg
# 1.3753292560577393
# Processing data/queries/p9_q4.jpg
# 1.287980556488037
# Processing data/queries/p9_q5.jpg
# 1.2993009090423584
# Processing data/queries/p9_q6.jpg
# 1.1947805881500244
# Processing data/queries/p9_q7.jpg
# 1.2050907611846924
# Processing data/queries/p9_q8.jpg
# 1.4954123497009277
# Processing data/queries/p9_q9.jpg
# 1.5970652103424072
# Processing data/queries/p9_q10.jpg
# 1.3661532402038574
# Processing data/queries/p10_q1.jpg
# 1.166987657546997
# Processing data/queries/p10_q2.jpg
# 1.1738901138305664
# Processing data/queries/p10_q3.jpg
# 1.3387107849121094
# Processing data/queries/p10_q4.jpg
# 1.424471139907837
# Processing data/queries/p10_q5.jpg
# 1.2811963558197021
# Processing data/queries/p10_q6.jpg
# 1.1810827255249023
# Processing data/queries/p10_q7.jpg
# 1.2028634548187256
# Processing data/queries/p10_q8.jpg
# 1.23081636428833
# Processing data/queries/p10_q9.jpg
# 1.2214057445526123
# Processing data/queries/p10_q10.jpg
# 1.246988296508789
# Processing data/queries/p12_q1.jpg
# 1.0493073463439941
# Processing data/queries/p12_q2.jpg
# 1.257875919342041
# Processing data/queries/p12_q3.jpg
# 1.4244823455810547
# Processing data/queries/p12_q4.jpg
# 1.4026257991790771
# Processing data/queries/p12_q5.jpg
# 1.1091830730438232
# Processing data/queries/p12_q6.jpg
# 1.3784337043762207
# Processing data/queries/p12_q7.jpg
# 1.5891411304473877
# Processing data/queries/p12_q8.jpg
# 1.3525972366333008
# Processing data/queries/p12_q9.jpg
# 1.166334867477417
# Processing data/queries/p12_q10.jpg
# 1.027209758758545
# Processing data/queries/p13_q1.jpg
# 1.5445516109466553
# Processing data/queries/p13_q2.jpg
# 1.4350104331970215
# Processing data/queries/p13_q3.jpg
# 1.1797680854797363
# Processing data/queries/p13_q4.jpg
# 1.1435282230377197
# Processing data/queries/p13_q5.jpg
# 1.3106510639190674
# Processing data/queries/p13_q6.jpg
# 1.3870391845703125
# Processing data/queries/p13_q7.jpg
# 1.051156997680664
# Processing data/queries/p13_q8.jpg
# 1.3574914932250977
# Processing data/queries/p13_q9.jpg
# 1.1334912776947021
# Processing data/queries/p13_q10.jpg
# 1.2405178546905518
# Processing data/queries/p14_q1.jpg
# 1.0314769744873047
# Processing data/queries/p14_q2.jpg
# 1.1225395202636719
# Processing data/queries/p14_q3.jpg
# 1.0260648727416992
# Processing data/queries/p14_q4.jpg
# 1.299487590789795
# Processing data/queries/p14_q5.jpg
# 0.9910426139831543
# Processing data/queries/p14_q6.jpg
# 0.9923989772796631
# Processing data/queries/p14_q7.jpg
# 0.8527891635894775
# Processing data/queries/p14_q8.jpg
# 0.9801323413848877
# Processing data/queries/p14_q9.jpg
# 1.0118727684020996
# Processing data/queries/p14_q10.jpg
# 0.9178817272186279
# Processing data/queries/p16_q1.jpg
# 1.3070833683013916
# Processing data/queries/p16_q2.jpg
# 1.3794963359832764
# Processing data/queries/p16_q3.jpg
# 1.4908993244171143
# Processing data/queries/p16_q4.jpg
# 1.2401010990142822
# Processing data/queries/p16_q5.jpg
# 1.1687281131744385
# Processing data/queries/p16_q6.jpg
# 1.2670812606811523
# Processing data/queries/p16_q7.jpg
# 1.1994047164916992
# Processing data/queries/p16_q8.jpg
# 1.1841328144073486
# Processing data/queries/p16_q9.jpg
# 1.2240514755249023
# Processing data/queries/p16_q10.jpg
# 1.1574409008026123
# Processing data/queries/p17_q1.jpg
# 1.0620379447937012
# Processing data/queries/p17_q2.jpg
# 1.0576553344726562
# Processing data/queries/p17_q3.jpg
# 1.0473134517669678
# Processing data/queries/p17_q4.jpg
# 0.9858419895172119
# Processing data/queries/p17_q5.jpg
# 1.157214641571045
# Processing data/queries/p17_q6.jpg
# 1.293483018875122
# Processing data/queries/p17_q7.jpg
# 0.9797677993774414
# Processing data/queries/p17_q8.jpg
# 1.059927225112915
# Processing data/queries/p17_q9.jpg
# 1.0139596462249756
# Processing data/queries/p17_q10.jpg
# 0.9771115779876709
# Processing data/queries/p18_q1.jpg
# 1.2664940357208252
# Processing data/queries/p18_q2.jpg
# 1.2681035995483398
# Processing data/queries/p18_q3.jpg
# 1.0994586944580078
# Processing data/queries/p18_q4.jpg
# 1.32596755027771
# Processing data/queries/p18_q5.jpg
# 1.4905400276184082
# Processing data/queries/p18_q6.jpg
# 1.0264322757720947
# Processing data/queries/p18_q7.jpg
# 0.9661581516265869
# Processing data/queries/p18_q8.jpg
# 1.1030869483947754
# Processing data/queries/p18_q9.jpg
# 1.252143144607544
# Processing data/queries/p18_q10.jpg
# 1.417853593826294
# Processing data/queries/p19_q1.jpg
# 1.0003347396850586
# Processing data/queries/p19_q2.jpg
# 0.9894139766693115
# Processing data/queries/p19_q3.jpg
# 0.9827907085418701
# Processing data/queries/p19_q4.jpg
# 1.0037314891815186
# Processing data/queries/p19_q5.jpg
# 1.105135202407837
# Processing data/queries/p19_q6.jpg
# 0.9738836288452148
# Processing data/queries/p19_q7.jpg
# 1.0448079109191895
# Processing data/queries/p19_q8.jpg
# 1.0733520984649658
# Processing data/queries/p19_q9.jpg
# 1.1907763481140137
# Processing data/queries/p19_q10.jpg
# 0.9938070774078369
# Processing data/queries/p20_q1.jpg
# 0.9741537570953369
# Processing data/queries/p20_q2.jpg
# 1.0395183563232422
# Processing data/queries/p20_q3.jpg
# 1.0323681831359863
# Processing data/queries/p20_q4.jpg
# 1.0249416828155518
# Processing data/queries/p20_q5.jpg
# 1.069657802581787
# Processing data/queries/p20_q6.jpg
# 1.0845026969909668
# Processing data/queries/p20_q7.jpg
# 1.0512032508850098
# Processing data/queries/p20_q8.jpg
# 0.9783282279968262
# Processing data/queries/p20_q9.jpg
# 1.0152530670166016
# Processing data/queries/p20_q10.jpg
# 1.0580902099609375
# Processing data/queries/p22_q1.jpg
# 1.1892509460449219
# Processing data/queries/p22_q2.jpg
# 1.0979809761047363
# Processing data/queries/p22_q3.jpg
# 1.0960845947265625
# Processing data/queries/p22_q4.jpg
# 1.2783503532409668
# Processing data/queries/p22_q5.jpg
# 1.199873924255371
# Processing data/queries/p22_q6.jpg
# 1.3957412242889404
# Processing data/queries/p22_q7.jpg
# 1.1799733638763428
# Processing data/queries/p22_q8.jpg
# 1.1292059421539307
# Processing data/queries/p22_q9.jpg
# 1.1506874561309814
# Processing data/queries/p22_q10.jpg
# 1.118518352508545
# Processing data/queries/p23_q1.jpg
# 1.1785292625427246
# Processing data/queries/p23_q2.jpg
# 1.221818208694458
# Processing data/queries/p23_q3.jpg
# 1.1008150577545166
# Processing data/queries/p23_q4.jpg
# 1.0994133949279785
# Processing data/queries/p23_q5.jpg
# 1.2945818901062012
# Processing data/queries/p23_q6.jpg
# 1.5842301845550537
# Processing data/queries/p23_q7.jpg
# 1.2699778079986572
# Processing data/queries/p23_q8.jpg
# 1.227828025817871
# Processing data/queries/p23_q9.jpg
# 1.422428846359253
# Processing data/queries/p23_q10.jpg
# 1.1724269390106201
# Processing data/queries/p24_q1.jpg
# 1.081538438796997
# Processing data/queries/p24_q2.jpg
# 1.1500332355499268
# Processing data/queries/p24_q3.jpg
# 1.1566412448883057
# Processing data/queries/p24_q4.jpg
# 1.5155677795410156
# Processing data/queries/p24_q5.jpg
# 1.198808193206787
# Processing data/queries/p24_q6.jpg
# 1.1627626419067383
# Processing data/queries/p24_q7.jpg
# 1.4306330680847168
# Processing data/queries/p24_q8.jpg
# 1.2772603034973145
# Processing data/queries/p24_q9.jpg
# 1.1706323623657227
# Processing data/queries/p24_q10.jpg
# 1.060229778289795
# Processing data/queries/p26_q1.jpg
# 1.1767537593841553
# Processing data/queries/p26_q2.jpg
# 1.4787366390228271
# Processing data/queries/p26_q3.jpg
# 1.5753889083862305
# Processing data/queries/p26_q4.jpg
# 1.6011853218078613
# Processing data/queries/p26_q5.jpg
# 1.4455370903015137
# Processing data/queries/p26_q6.jpg
# 1.2219386100769043
# Processing data/queries/p26_q7.jpg
# 1.4899392127990723
# Processing data/queries/p26_q8.jpg
# 1.5598597526550293
# Processing data/queries/p26_q9.jpg
# 1.7035980224609375
# Processing data/queries/p26_q10.jpg
# 1.1999132633209229
# Processing data/queries/p27_q1.jpg
# 1.1880877017974854
# Processing data/queries/p27_q2.jpg
# 1.2572619915008545
# Processing data/queries/p27_q3.jpg
# 1.242347002029419
# Processing data/queries/p27_q4.jpg
# 1.184056282043457
# Processing data/queries/p27_q5.jpg
# 1.0445451736450195
# Processing data/queries/p27_q6.jpg
# 1.235990285873413
# Processing data/queries/p27_q7.jpg
# 1.434830904006958
# Processing data/queries/p27_q8.jpg
# 1.3316898345947266
# Processing data/queries/p27_q9.jpg
# 1.3281195163726807
# Processing data/queries/p27_q10.jpg
# 1.262744665145874
# Processing data/queries/p28_q1.jpg
# 1.3575916290283203
# Processing data/queries/p28_q2.jpg
# 1.2259283065795898
# Processing data/queries/p28_q3.jpg
# 1.209656000137329
# Processing data/queries/p28_q4.jpg
# 1.2054805755615234
# Processing data/queries/p28_q5.jpg
# 1.44425368309021
# Processing data/queries/p28_q6.jpg
# 1.2460906505584717
# Processing data/queries/p28_q7.jpg
# 1.1935179233551025
# Processing data/queries/p28_q8.jpg
# 1.2629387378692627
# Processing data/queries/p28_q9.jpg
# 1.3763554096221924
# Processing data/queries/p28_q10.jpg
# 1.2265815734863281
# Processing data/queries/p29_q1.jpg
# 1.076362133026123
# Processing data/queries/p29_q2.jpg
# 0.9687669277191162
# Processing data/queries/p29_q3.jpg
# 0.9972338676452637
# Processing data/queries/p29_q4.jpg
# 0.9245967864990234
# Processing data/queries/p29_q5.jpg
# 1.0521719455718994
# Processing data/queries/p29_q6.jpg
# 1.09535551071167
# Processing data/queries/p29_q7.jpg
# 0.9675195217132568
# Processing data/queries/p29_q8.jpg
# 0.932138204574585
# Processing data/queries/p29_q9.jpg
# 0.9556751251220703
# Processing data/queries/p29_q10.jpg
# 0.9066545963287354
# Processing data/queries/p30_q1.jpg
# 0.9493513107299805
# Processing data/queries/p30_q2.jpg
# 1.0336382389068604
# Processing data/queries/p30_q3.jpg
# 1.1254711151123047
# Processing data/queries/p30_q4.jpg
# 1.1739113330841064
# Processing data/queries/p30_q5.jpg
# 1.0946435928344727
# Processing data/queries/p30_q6.jpg
# 0.9989395141601562
# Processing data/queries/p30_q7.jpg
# 1.0506689548492432
# Processing data/queries/p30_q8.jpg
# 0.9053080081939697
# Processing data/queries/p30_q9.jpg
# 1.2736210823059082
# Processing data/queries/p30_q10.jpg
# 0.9941837787628174
# Processing data/queries/p32_q1.jpg
# 0.9626662731170654
# Processing data/queries/p32_q2.jpg
# 0.988370418548584
# Processing data/queries/p32_q3.jpg
# 1.0403411388397217
# Processing data/queries/p32_q4.jpg
# 1.0765104293823242
# Processing data/queries/p32_q5.jpg
# 0.9876041412353516
# Processing data/queries/p32_q6.jpg
# 1.0610003471374512
# Processing data/queries/p32_q7.jpg
# 1.2128183841705322
# Processing data/queries/p32_q8.jpg
